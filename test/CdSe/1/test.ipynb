# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine

# %%
from deepmd.calculator import DP
# Out:
# 2022-03-22 02:12:09.997989: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 02:12:09.998153: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
setting = {'basis':'def2-tzvp', 'ecp':'lanl2dz', 'spin':0, 'xc':'pbe', 'restricted':True, 'verbose':3, 'max_cycle':200}
geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./CdSe_1.xyz',**setting)
geo.opt_algorithm = 'lbfgs'
geo.kernel()
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.10000000000 will be used
# converged SCF energy = -57.2253404965652
# --------------- RKS gradients ---------------
#          x                y                z
# 0 Cd    -0.0000000001     0.0000000001     0.0274744722
# 1 Se    -0.0000000001     0.0000000001     0.4657801756
# ----------------------------------------------
# --------------- RKS gradients ---------------
#          x                y                z
# 0 Cd    -0.0000000001     0.0000000001     0.0274744722
# 1 Se    -0.0000000001     0.0000000001     0.4657801756
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-03-22 08:29:56.043772: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 08:29:56.043941: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# 2022-03-22 08:30:02.603730: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 08:30:02.617237: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-22 08:30:02.617371: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2240 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2242 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2243 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2244 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2246 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2245 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2247 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2248 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2249 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2250 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2251 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2252 thread 11 bound to OS proc set 11
# /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data_system.py:159: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (16 > 1)
#   (self.system_dirs[ii], chk_ret[0], self.batch_size[ii], chk_ret[1]))
# DEEPMD INFO    training data with min nbor dist: 2.584
# DEEPMD INFO    training data with max nbor size: [1, 1]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/dgg95223/deepmd-kit/_skbuild/linux-x86_64-3.7/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Deng-PC
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       2      16       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2239 thread 12 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2253 thread 13 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2254 thread 14 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2255 thread 15 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2256 thread 16 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2257 thread 17 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2258 thread 18 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2259 thread 19 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2260 thread 20 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2261 thread 21 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2262 thread 22 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2263 thread 23 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2179 thread 24 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 5000, decay_rate 0.598777, final lr will be 3.51e-08
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2230 thread 25 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2264 thread 26 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2265 thread 27 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2266 thread 28 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2267 thread 29 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2268 thread 30 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2269 thread 31 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2270 thread 32 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2271 thread 33 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2272 thread 34 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2273 thread 35 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2274 thread 36 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2237 thread 37 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2276 thread 38 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2277 thread 39 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2278 thread 40 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2279 thread 41 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2280 thread 42 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2281 thread 43 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2282 thread 44 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2283 thread 45 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2284 thread 46 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2285 thread 47 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2286 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2231 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2289 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2290 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2291 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2292 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2293 thread 54 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2294 thread 55 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2295 thread 56 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2296 thread 57 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2297 thread 58 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2298 thread 59 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2299 thread 60 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2235 thread 61 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2300 thread 62 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2301 thread 63 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2302 thread 64 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2303 thread 65 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2304 thread 66 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2305 thread 67 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2306 thread 68 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2307 thread 69 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2308 thread 70 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2309 thread 71 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2310 thread 72 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2234 thread 73 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2311 thread 74 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2312 thread 75 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2313 thread 76 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2314 thread 77 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2315 thread 78 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2316 thread 79 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2317 thread 80 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2318 thread 81 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2319 thread 82 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2320 thread 83 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2321 thread 84 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2238 thread 85 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2322 thread 86 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2323 thread 87 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2324 thread 88 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2325 thread 89 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2326 thread 90 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2327 thread 91 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2328 thread 92 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2329 thread 93 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2330 thread 94 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2331 thread 95 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2332 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2232 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2333 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2334 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2335 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2336 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2337 thread 102 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2338 thread 103 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2339 thread 104 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2340 thread 105 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2341 thread 106 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2342 thread 107 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2343 thread 108 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2233 thread 109 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2344 thread 110 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2345 thread 111 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2346 thread 112 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2347 thread 113 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2348 thread 114 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2349 thread 115 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2350 thread 116 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2351 thread 117 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2352 thread 118 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2353 thread 119 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2354 thread 120 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2229 thread 121 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2355 thread 122 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2356 thread 123 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2357 thread 124 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2358 thread 125 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2359 thread 126 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2360 thread 127 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2361 thread 128 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2362 thread 129 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2363 thread 130 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2364 thread 131 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2365 thread 132 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2236 thread 133 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2366 thread 134 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2367 thread 135 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2368 thread 136 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2369 thread 137 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2370 thread 138 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2371 thread 139 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2372 thread 140 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2373 thread 141 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2374 thread 142 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2375 thread 143 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 2179 tid 2376 thread 144 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 2.66 s, testing time 0.00 s
# DEEPMD INFO    batch     200 training time 1.15 s, testing time 0.00 s
# DEEPMD INFO    batch     300 training time 1.15 s, testing time 0.00 s
# DEEPMD INFO    batch     400 training time 1.17 s, testing time 0.00 s
# DEEPMD INFO    batch     500 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch     600 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch     700 training time 1.18 s, testing time 0.00 s
# DEEPMD INFO    batch     800 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch     900 training time 1.14 s, testing time 0.00 s
# DEEPMD INFO    batch    1000 training time 1.17 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch    1200 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch    1300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    1400 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch    1500 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch    1600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    1700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    1800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    1900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch    2000 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2600 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch    2700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    2900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3000 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    3300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    3400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    3900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch    4000 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    4100 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    4200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    4300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    4400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    4500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    4600 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch    4700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    4800 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    4900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    5000 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    5100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    5200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    5300 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch    5400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    5500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    5600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    5700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    5800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    5900 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    6000 training time 1.06 s, testing time 0.00 s
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1058: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1058: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    6100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    6200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    6300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    6400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    6500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    6600 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    6700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    6800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    6900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    7100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    7400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    7800 training time 1.02 s, testing time 0.00 s
# DEEPMD INFO    batch    7900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    8100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    8700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch    8800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    8900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    9100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    9400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch    9500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch    9900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   10000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   10100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   10200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   10300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   10400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   10500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   10600 training time 1.02 s, testing time 0.00 s
# DEEPMD INFO    batch   10700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   10800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   10900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   11100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   11500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   11800 training time 1.02 s, testing time 0.00 s
# DEEPMD INFO    batch   11900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   12000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   12100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   12200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   12300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   12400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   12500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   12600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   12700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   12800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   12900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   13000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   13100 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   13200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   13300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   13400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   13500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   13600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   13700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   13800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   13900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   14000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   14100 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   14200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   14300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   14400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   14500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   14600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   14700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   14800 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   14900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   15000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   15100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   15200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   15300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   15400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   15500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   15600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   15700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   15800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   15900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   16100 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   16200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   16800 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   16900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   17000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   17100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   17200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   17300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   17400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   17500 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   17600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   17700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   17800 training time 1.02 s, testing time 0.00 s
# DEEPMD INFO    batch   17900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   18100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18200 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   18300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   18900 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   19000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   19100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   19200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   19300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   19400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   19500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   19600 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   19700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   19800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   19900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   20000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   20100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   20200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   20300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   20400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   20500 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   20600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   20700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   20800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   20900 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   21000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   21100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21600 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   21700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   21900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   22000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   22100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   22200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   22300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   22400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   22500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   22600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   22700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   22800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   22900 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   23000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   23100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   23200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   23300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   23400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   23500 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   23600 training time 1.10 s, testing time 0.00 s
# DEEPMD INFO    batch   23700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   23800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   23900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   24100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24300 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   24400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   24800 training time 1.02 s, testing time 0.00 s
# DEEPMD INFO    batch   24900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   25000 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   25100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   25200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   25300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   25400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   25500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   25600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   25700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   25800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   25900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   26000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   26100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   26200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   26300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   26400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   26500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   26600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   26700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   26800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   26900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   27000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   27100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   27200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   27300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   27400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   27500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   27600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   27700 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   27800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   27900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   28000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   28100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   28200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   28300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   28400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   28500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   28600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   28700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   28800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   28900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   29000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   29100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   29200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   29300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   29400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   29500 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   29600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   29700 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   29800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   29900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   30000 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   30100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   30200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   30300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   30400 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   30500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   30600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   30700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   30800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   30900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   31000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   31100 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   31200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   31300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   31400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   31500 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   31600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   31700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   31800 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   31900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   32100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32400 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   32500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   32600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   32900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   33000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   33100 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   33200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   33300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   33400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   33500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   33600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   33700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   33800 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   33900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   34100 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34500 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   34600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34700 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   34800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   34900 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   35000 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   35100 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   35200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   35300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   35400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   35500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   35600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   35700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   35800 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   35900 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   36000 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   36100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   36200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   36300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   36400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   36500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   36600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   36700 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   36800 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   36900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   37000 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   37100 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   37200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   37300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   37400 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   37500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   37600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   37700 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   37800 training time 1.14 s, testing time 0.00 s
# DEEPMD INFO    batch   37900 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   38000 training time 1.10 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   38100 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   38200 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   38300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   38400 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   38500 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   38600 training time 1.11 s, testing time 0.00 s
# DEEPMD INFO    batch   38700 training time 1.16 s, testing time 0.01 s
# DEEPMD INFO    batch   38800 training time 1.18 s, testing time 0.01 s
# DEEPMD INFO    batch   38900 training time 1.11 s, testing time 0.00 s
# DEEPMD INFO    batch   39000 training time 1.11 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   39100 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   39200 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   39300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   39400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   39500 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   39600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   39700 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   39800 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   39900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   40000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   40100 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   40200 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   40300 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   40400 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   40500 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   40600 training time 1.33 s, testing time 0.00 s
# DEEPMD INFO    batch   40700 training time 1.17 s, testing time 0.00 s
# DEEPMD INFO    batch   40800 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch   40900 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch   41000 training time 1.15 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   41100 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   41200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   41300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   41400 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   41500 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   41600 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   41700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   41800 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   41900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   42000 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   42100 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   42200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   42300 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   42400 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   42500 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   42600 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   42700 training time 1.31 s, testing time 0.00 s
# DEEPMD INFO    batch   42800 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch   42900 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch   43000 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   43100 training time 1.12 s, testing time 0.00 s
# DEEPMD INFO    batch   43200 training time 1.16 s, testing time 0.00 s
# DEEPMD INFO    batch   43300 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch   43400 training time 1.10 s, testing time 0.00 s
# DEEPMD INFO    batch   43500 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   43600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   43700 training time 1.14 s, testing time 0.00 s
# DEEPMD INFO    batch   43800 training time 1.16 s, testing time 0.00 s
# DEEPMD INFO    batch   43900 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   44000 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   44100 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   44200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   44300 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   44400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   44500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   44600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   44700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   44800 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   44900 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   45000 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   45100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   45200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   45300 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   45400 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   45500 training time 1.11 s, testing time 0.00 s
# DEEPMD INFO    batch   45600 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   45700 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   45800 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   45900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   46000 training time 1.12 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   46100 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    batch   46200 training time 1.07 s, testing time 0.01 s
# DEEPMD INFO    batch   46300 training time 1.34 s, testing time 0.00 s
# DEEPMD INFO    batch   46400 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch   46500 training time 1.28 s, testing time 0.00 s
# DEEPMD INFO    batch   46600 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch   46700 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch   46800 training time 1.16 s, testing time 0.01 s
# DEEPMD INFO    batch   46900 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch   47000 training time 1.18 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   47100 training time 1.12 s, testing time 0.00 s
# DEEPMD INFO    batch   47200 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   47300 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   47400 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   47500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   47600 training time 1.03 s, testing time 0.00 s
# DEEPMD INFO    batch   47700 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   47800 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   47900 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   48000 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   48100 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   48200 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   48300 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   48400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   48500 training time 1.10 s, testing time 0.00 s
# DEEPMD INFO    batch   48600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   48700 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   48800 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   48900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   49000 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   49100 training time 1.11 s, testing time 0.00 s
# DEEPMD INFO    batch   49200 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   49300 training time 1.12 s, testing time 0.00 s
# DEEPMD INFO    batch   49400 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   49500 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   49600 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   49700 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   49800 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   49900 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   50000 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   50100 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   50200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   50300 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   50400 training time 1.05 s, testing time 0.00 s
# DEEPMD INFO    batch   50500 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   50600 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   50700 training time 1.13 s, testing time 0.00 s
# DEEPMD INFO    batch   50800 training time 1.18 s, testing time 0.00 s
# DEEPMD INFO    batch   50900 training time 1.16 s, testing time 0.00 s
# DEEPMD INFO    batch   51000 training time 1.10 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   51100 training time 1.09 s, testing time 0.00 s
# DEEPMD INFO    batch   51200 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   51300 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   51400 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   51500 training time 1.06 s, testing time 0.00 s
# DEEPMD INFO    batch   51600 training time 1.04 s, testing time 0.00 s
# DEEPMD INFO    batch   51700 training time 1.07 s, testing time 0.00 s
# DEEPMD INFO    batch   51800 training time 1.15 s, testing time 0.00 s
# DEEPMD INFO    batch   51900 training time 1.10 s, testing time 0.00 s
# DEEPMD INFO    batch   52000 training time 1.08 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   52100 training time 1.05 s, testing time 0.00 s
# Traceback (most recent call last):
#   File "/home/dgg95223/venv/bin/dp", line 8, in <module>
#     sys.exit(main())
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/main.py", line 473, in main
#     train_dp(**dict_args)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/train.py", line 106, in train
#     _do_work(jdata, run_opt, is_compress)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/train.py", line 167, in _do_work
#     model.train(train_data, valid_data)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/train/trainer.py", line 497, in train
#     train_batch = train_data.get_batch()
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data_system.py", line 335, in get_batch
#     b_data = self.data_systems[self.pick_idx].get_batch(self.batch_size[self.pick_idx])
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data.py", line 212, in get_batch
#     self._load_batch_set (self.train_dirs[self.set_count % self.get_numb_set()])
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data.py", line 383, in _load_batch_set
#     self.batch_set = self._load_set(set_name)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data.py", line 422, in _load_set
#     coord = path.load_numpy().astype(GLOBAL_NP_FLOAT_PRECISION)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/path.py", line 134, in load_numpy
#     return np.load(str(self.path))
#   File "/home/dgg95223/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26551/1650625337.py in <module>
#       2 geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./CdSe_1.xyz',**setting)
#       3 geo.opt_algorithm = 'lbfgs'
# ----> 4 geo.kernel()
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/main.py in kernel(self)
#      95 			'''%iter)
#      96                         ML = ML_engine.MLEngine(work_path=self.work_path, ml_engine=self.ml_engine).build()
# ---> 97                         ML.run()
#      98
#      99 			Opt = optimizer.Optimizer(xyz_path=self.xyz_path,
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/ML_engine.py in run(self)
#      34     def run(self):
#      35
# ---> 36         self.training()
#      37         self.freeze()
#      38         self.compress()
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/ML_engine.py in training(self)
#      21
#      22     def training(self):
# ---> 23         train = subprocess.run('dp train %s'%self.input_path, shell=True)
#      24         assert train.returncode == 0, 'An error occurred during training process.'
#      25
#
# ~/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
# --> 490             stdout, stderr = process.communicate(input, timeout=timeout)
#     491         except TimeoutExpired as exc:
#     492             process.kill()
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     954                 stderr = self.stderr.read()
#     955                 self.stderr.close()
# --> 956             self.wait()
#     957         else:
#     958             if timeout is not None:
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#    1017             endtime = _time() + timeout
#    1018         try:
# -> 1019             return self._wait(timeout=timeout)
#    1020         except KeyboardInterrupt:
#    1021             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1651                         if self.returncode is not None:
#    1652                             break  # Another thread waited.
# -> 1653                         (pid, sts) = self._try_wait(0)
#    1654                         # Check the pid and loop as waitpid has been known to
#    1655                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1609             """All callers to this function MUST hold self._waitpid_lock."""
#    1610             try:
# -> 1611                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1612             except ChildProcessError:
#    1613                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
from pyscf import gto, scf

mol = gto.Mole(atom='''
O        3.37554198       1.98306445       1.77042260
O       26.17128840       1.15953296       1.70257011
H        3.48718928       1.81771738       1.72566221
H        3.36969874       1.99171817       1.77276519
H       26.20859573       1.24129313       1.88623203
H       26.16933587       1.15525391       1.69295785''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
# Out:
# converged SCF energy = 610.156839488383
# 610.1568394883828

# %%
mol = gto.Mole(atom='''
O        3.85028343       4.33435074      -1.46283114
O       32.83434364       4.59371931      -0.64864949
H        3.22764867       0.72764750       3.29111982
H        3.15449789       0.73050176       3.44056131
H       22.91529053      -0.47107633       3.00121399
H       22.79958584      -0.56656299       2.92919549
''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
# Out:
# SCF not converged.
# SCF energy = -144.603063781376
# -144.603063781376

# %%
from pyscf import gto, scf

mol = gto.Mole(atom='''
O   3.63802      1.57110      1.76000
O  26.36198      1.57110      1.76000
H   3.95828      2.55412      1.74392
H   2.63613      1.66728      1.76493
H  26.09174      0.99418      2.56104
H  26.09550      0.99080      0.96072''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
print('111',mf.e_tot)
# Out:
# converged SCF energy = -151.950875830031
# 111 -151.9508758300306

# %%
from pyscf.data.nist import BOHR ,HARTREE2EV
print(0.00045 * HARTREE2EV/BOHR)
# Out:
# 0.023139930171428326
