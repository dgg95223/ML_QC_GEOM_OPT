# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine

# %%
from deepmd.calculator import DP
# Out:
# 2022-03-22 16:17:53.643849: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:17:53.643908: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
setting = {'basis':'def2-svp', 'ecp':'lanl2dz', 'spin':0, 'xc':'pbe', 'restricted':True, 'verbose':4, 'max_cycle':500, 'dm0':1}
geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./CdSe_1.xyz',**setting)
geo.opt_algorithm = 'lbfgs'
geo.kernel()
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.10000000000 will be used
# ******** <class 'pyscf.dft.rks.RKS'> ********
# method = RKS-RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-12
# SCF conv_tol_grad = None
# SCF max_cycles = 500
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /home/jingheng/ML_QC_GEOM_OPT/test/CdSe/1/tmp7oxhbmat
# max_memory 4000 MB (current use 723 MB)
# XC library pyscf.dft.libxc version 5.2.0
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018)
# XC functionals = LDA,VWN
#     P. A. M. Dirac, Math. Proc. Cambridge Philos. Soc. 26, 376 (1930)
#     F. Bloch, Z. Phys. 57, 545 (1929)
#     S. H. Vosko, L. Wilk, and M. Nusair, Can. J. Phys. 58, 1200 (1980)
# small_rho_cutoff = 1e-07
# Set gradient conv threshold to 1e-06
# init E= -13.9206932846668
#   HOMO = -0.391033990473194  LUMO = -0.36995003777866
# cycle= 1 E= -56.918048064756  delta_E=  -43  |g|= 0.826  |ddm|=  3.4
#   HOMO = -0.22035980700273  LUMO = -0.108102874953365
# cycle= 2 E= -56.5671477915394  delta_E= 0.351  |g|= 1.25  |ddm|= 2.78
#
# WARN: HOMO -0.1443543704669 == LUMO -0.144354370466891
#
# cycle= 3 E= -56.7583340611232  delta_E= -0.191  |g|= 0.756  |ddm|= 2.76
#   HOMO = -0.192174419397434  LUMO = -0.156700444765948
# cycle= 4 E= -57.1310861452394  delta_E= -0.373  |g|= 0.187  |ddm|= 2.26
#   HOMO = -0.195378439454787  LUMO = -0.16959034339657
# cycle= 5 E= -57.1364330497784  delta_E= -0.00535  |g|= 0.0975  |ddm|= 0.107
#   HOMO = -0.180378303583858  LUMO = -0.168110787711846
# cycle= 6 E= -57.1397714288489  delta_E= -0.00334  |g|= 0.0705  |ddm|= 0.269
#   HOMO = -0.187260878153405  LUMO = -0.174985052821336
# cycle= 7 E= -57.1418286815172  delta_E= -0.00206  |g|= 0.00638  |ddm|= 0.0962
#   HOMO = -0.188547871248845  LUMO = -0.174730703211169
# cycle= 8 E= -57.1418463589285  delta_E= -1.77e-05  |g|= 0.00143  |ddm|= 0.0125
#   HOMO = -0.188440253661077  LUMO = -0.174689934670046
# cycle= 9 E= -57.1418472328471  delta_E= -8.74e-07  |g|= 0.000128  |ddm|= 0.00189
#   HOMO = -0.188467834009451  LUMO = -0.174724400289687
# cycle= 10 E= -57.1418472349503  delta_E= -2.1e-09  |g|= 0.00011  |ddm|= 0.000437
#   HOMO = -0.188471930440387  LUMO = -0.174719001739742
# cycle= 11 E= -57.1418472411373  delta_E= -6.19e-09  |g|= 6.47e-06  |ddm|= 0.00022
#   HOMO = -0.188471572107817  LUMO = -0.174718993089421
# cycle= 12 E= -57.1418472411486  delta_E= -1.14e-11  |g|= 1.01e-07  |ddm|= 6.88e-06
#   HOMO = -0.188471588230611  LUMO = -0.174719007921886
# cycle= 13 E= -57.1418472411488  delta_E= -1.56e-13  |g|= 2.06e-08  |ddm|= 1.69e-07
#   HOMO = -0.188471582938834  LUMO = -0.174719007830066
# Extra cycle  E= -57.1418472411488  delta_E=    0  |g|= 7.9e-08  |ddm|= 1.5e-07
# converged SCF energy = -57.1418472411488
#
#
# ******** <class 'pyscf.grad.rks.Gradients'> for <class 'pyscf.dft.rks.RKS'> ********
# unit = Eh/Bohr
# max_memory 4000 MB (current use 725 MB)
# grid_response = False
# --------------- RKS gradients ---------------
#          x                y                z
# 0 Cd    -0.0000000000     0.0000000000    -0.0062098902
# 1 Se     0.0000000000    -0.0000000000     0.0062101641
# ----------------------------------------------
# main.py 81 QC_coords0: [[ 0.          0.          2.26767135]
#  [ 0.          0.         -2.26767135]]
#
#
# ******** <class 'pyscf.grad.rks.Gradients'> for <class 'pyscf.dft.rks.RKS'> ********
# unit = Eh/Bohr
# max_memory 4000 MB (current use 726 MB)
# grid_response = False
# --------------- RKS gradients ---------------
#          x                y                z
# 0 Cd    -0.0000000000     0.0000000000    -0.0062098902
# 1 Se     0.0000000000    -0.0000000000     0.0062101641
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-03-22 16:39:35.328154: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:39:35.328196: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# /home/jingheng/venv/lib/python3.9/site-packages/deepmd/utils/data_system.py:158: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (2 > 1)
#   warnings.warn("system %s required batch size is larger than the size of the dataset %s (%d > %d)" % \
# 2022-03-22 16:39:38.809216: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 16:39:38.811789: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-22 16:39:38.811823: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-22 16:39:38.811851: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6070 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6072 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6074 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6073 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6075 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6077 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6079 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6078 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6076 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6080 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6081 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6082 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6083 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6084 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6085 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6086 thread 15 bound to OS proc set 15
# DEEPMD INFO    training data with min nbor dist: 2.4
# DEEPMD INFO    training data with max nbor size: [1, 1]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       2       2       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6068 thread 16 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6087 thread 17 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6088 thread 18 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6091 thread 21 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6089 thread 19 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6090 thread 20 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6092 thread 22 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6093 thread 23 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6094 thread 24 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6096 thread 26 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6095 thread 25 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6097 thread 27 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6099 thread 29 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6098 thread 28 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6100 thread 30 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6101 thread 31 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6004 thread 32 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 100, decay_rate 0.358534, final lr will be 3.51e-08
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6059 thread 33 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6103 thread 35 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6102 thread 34 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6104 thread 36 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6105 thread 37 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6106 thread 38 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6107 thread 39 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6108 thread 40 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6110 thread 42 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6109 thread 41 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6111 thread 43 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6112 thread 44 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6113 thread 45 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6114 thread 46 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6115 thread 47 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6116 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6062 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6117 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6118 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6119 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6120 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6121 thread 54 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6122 thread 55 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6123 thread 56 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6124 thread 57 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6125 thread 58 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6126 thread 59 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6127 thread 60 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6128 thread 61 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6129 thread 62 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6130 thread 63 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6131 thread 64 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6057 thread 65 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6132 thread 66 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6133 thread 67 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6134 thread 68 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6135 thread 69 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6137 thread 71 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6136 thread 70 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6138 thread 72 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6139 thread 73 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6140 thread 74 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6141 thread 75 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6145 thread 79 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6144 thread 78 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6143 thread 77 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6142 thread 76 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6146 thread 80 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6069 thread 81 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6147 thread 82 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6148 thread 83 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6149 thread 84 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6150 thread 85 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6151 thread 86 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6152 thread 87 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6153 thread 88 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6154 thread 89 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6155 thread 90 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6156 thread 91 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6157 thread 92 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6158 thread 93 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6159 thread 94 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6160 thread 95 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6161 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6061 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6163 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6162 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6164 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6165 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6166 thread 102 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6167 thread 103 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6168 thread 104 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6169 thread 105 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6170 thread 106 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6171 thread 107 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6172 thread 108 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6173 thread 109 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6174 thread 110 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6175 thread 111 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6176 thread 112 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6065 thread 113 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6177 thread 114 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6178 thread 115 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6179 thread 116 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6180 thread 117 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6181 thread 118 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6182 thread 119 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6183 thread 120 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6184 thread 121 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6185 thread 122 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6186 thread 123 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6187 thread 124 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6188 thread 125 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6189 thread 126 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6190 thread 127 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6191 thread 128 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6063 thread 129 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6192 thread 130 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6193 thread 131 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6194 thread 132 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6195 thread 133 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6196 thread 134 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6197 thread 135 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6198 thread 136 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6199 thread 137 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6200 thread 138 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6201 thread 139 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6202 thread 140 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6203 thread 141 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6204 thread 142 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6205 thread 143 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6206 thread 144 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6064 thread 145 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6207 thread 146 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6208 thread 147 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6209 thread 148 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6210 thread 149 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6211 thread 150 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6212 thread 151 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6213 thread 152 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6214 thread 153 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6215 thread 154 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6216 thread 155 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6217 thread 156 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6218 thread 157 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6219 thread 158 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6220 thread 159 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6221 thread 160 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6058 thread 161 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6222 thread 162 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6223 thread 163 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6224 thread 164 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6225 thread 165 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6226 thread 166 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6227 thread 167 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6228 thread 168 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6229 thread 169 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6230 thread 170 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6231 thread 171 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6232 thread 172 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6233 thread 173 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6234 thread 174 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6235 thread 175 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6236 thread 176 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6060 thread 177 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6237 thread 178 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6238 thread 179 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6239 thread 180 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6240 thread 181 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6241 thread 182 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6242 thread 183 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6243 thread 184 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6244 thread 185 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6245 thread 186 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6246 thread 187 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6247 thread 188 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6248 thread 189 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6249 thread 190 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6250 thread 191 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6251 thread 192 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6055 thread 193 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6252 thread 194 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6253 thread 195 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6254 thread 196 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6255 thread 197 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6256 thread 198 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6257 thread 199 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6258 thread 200 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6259 thread 201 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6260 thread 202 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6261 thread 203 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6262 thread 204 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6263 thread 205 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6264 thread 206 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6265 thread 207 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6266 thread 208 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6066 thread 209 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6267 thread 210 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6268 thread 211 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6269 thread 212 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6270 thread 213 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6271 thread 214 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6272 thread 215 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6273 thread 216 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6274 thread 217 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6275 thread 218 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6276 thread 219 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6277 thread 220 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6278 thread 221 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6279 thread 222 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6280 thread 223 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6281 thread 224 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6056 thread 225 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6282 thread 226 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6283 thread 227 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6284 thread 228 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6285 thread 229 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6286 thread 230 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6287 thread 231 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6288 thread 232 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6289 thread 233 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6290 thread 234 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6291 thread 235 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6292 thread 236 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6293 thread 237 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6294 thread 238 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6295 thread 239 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6296 thread 240 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6067 thread 241 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6297 thread 242 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6298 thread 243 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6299 thread 244 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6300 thread 245 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6301 thread 246 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6302 thread 247 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6303 thread 248 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6304 thread 249 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6305 thread 250 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6306 thread 251 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6307 thread 252 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6308 thread 253 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6309 thread 254 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6310 thread 255 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6004 tid 6311 thread 256 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 1.39 s, testing time 0.00 s
# DEEPMD INFO    batch     200 training time 0.82 s, testing time 0.00 s
# DEEPMD INFO    batch     300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch     400 training time 0.83 s, testing time 0.00 s
# DEEPMD INFO    batch     500 training time 0.82 s, testing time 0.00 s
# DEEPMD INFO    batch     600 training time 0.83 s, testing time 0.00 s
# DEEPMD INFO    batch     700 training time 0.83 s, testing time 0.00 s
# DEEPMD INFO    batch     800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch     900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1000 training time 0.83 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    finished training
# DEEPMD INFO    wall time: 11.365 s
# 2022-03-22 16:39:52.433829: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:39:52.433873: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-22 16:39:54.470675: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-22 16:39:54.470718: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-22 16:39:54.470747: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-22 16:39:54.471008: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./model.ckpt-1000
# DEEPMD INFO    Restoring parameters from ./model.ckpt-1000
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    1150 ops in the final graph.
# 2022-03-22 16:39:55.447400: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:39:55.447439: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-22 16:39:57.038408: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-22 16:39:57.038451: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-22 16:39:57.038484: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-22 16:39:57.038705: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 1: compress the model
# DEEPMD WARNING Switch to serial execution due to lack of horovod module.
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    training data with lower boundary: -0.0854357657716761
# DEEPMD INFO    training data with upper boundary: 11.704699910719626
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6357 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6425 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6427 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6428 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6426 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6429 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6431 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6430 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6432 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6433 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6434 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6436 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6435 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6437 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6438 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6357 tid 6439 thread 15 bound to OS proc set 15
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    finished compressing
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 2: freeze the model
# INFO:tensorflow:Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    786 ops in the final graph.
# optimizer.py 77: [[ 0.   0.   1.2]
#  [ 0.   0.  -1.2]]
#        Step     Time          Energy          fmax
# LBFGS:    0 16:40:03    -1554.908863         0.319332
# LBFGS:    1 16:40:03    -1554.911798         0.324119
# LBFGS:    2 16:40:03    -1554.817316         0.163640
# LBFGS:    3 16:40:03    -1554.771528         0.074031
# LBFGS:    4 16:40:03    -1554.754793         0.030797
# LBFGS:    5 16:40:03    -1554.749937         0.011992
# main.py 94: QC_coords1 [[ 0.         0.         3.5495968]
#  [ 0.         0.        -3.5495968]]
#
#
# ******** <class 'pyscf.dft.rks.RKS'> ********
# method = RKS-RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-12
# SCF conv_tol_grad = None
# SCF max_cycles = 500
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /home/jingheng/ML_QC_GEOM_OPT/test/CdSe/1/tmp2753s16u
# max_memory 4000 MB (current use 726 MB)
# XC library pyscf.dft.libxc version 5.2.0
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018)
# XC functionals = LDA,VWN
#     P. A. M. Dirac, Math. Proc. Cambridge Philos. Soc. 26, 376 (1930)
#     F. Bloch, Z. Phys. 57, 545 (1929)
#     S. H. Vosko, L. Wilk, and M. Nusair, Can. J. Phys. 58, 1200 (1980)
# small_rho_cutoff = 1e-07
# Set gradient conv threshold to 1e-06
# init E= -56.922394816518
#
# WARN: HOMO -0.255171779859107 == LUMO -0.255171779842009
#
# cycle= 1 E= -56.9756158598876  delta_E= -0.0532  |g|= 0.319  |ddm|= 2.23
#   HOMO = -0.295203210600924  LUMO = -0.134662872221867
# cycle= 2 E= -56.3238850629367  delta_E= 0.652  |g|= 0.911  |ddm|= 2.73
#   HOMO = -0.161413152624986  LUMO = -0.158220302282143
# cycle= 3 E= -57.0056578645735  delta_E= -0.682  |g|= 0.252  |ddm|=  2.4
#   HOMO = -0.208595959807938  LUMO = -0.187973954613007
# cycle= 4 E= -57.0432582630839  delta_E= -0.0376  |g|= 0.212  |ddm|= 2.05
#   HOMO = -0.203047489104632  LUMO = -0.19693041542464
# cycle= 5 E= -57.0423032569389  delta_E= 0.000955  |g|= 0.198  |ddm|= 0.062
#   HOMO = -0.204349798730227  LUMO = -0.196491749046741
# cycle= 6 E= -57.0375664099081  delta_E= 0.00474  |g|= 0.213  |ddm|= 0.0386
#   HOMO = -0.186930343308222  LUMO = -0.183087040149297
# cycle= 7 E= -57.0193632676263  delta_E= 0.0182  |g|= 0.177  |ddm|= 2.08
#
# WARN: HOMO -0.192734683848697 == LUMO -0.192141712961222
#
# cycle= 8 E= -57.0222928832075  delta_E= -0.00293  |g|= 0.16  |ddm|= 0.0416
#   HOMO = -0.214444454279299  LUMO = -0.203082171834794
# cycle= 9 E= -56.8624789475325  delta_E= 0.16  |g|= 0.517  |ddm|= 2.24
#   HOMO = -0.208632611118633  LUMO = -0.204026932459279
# cycle= 10 E= -56.9193172026234  delta_E= -0.0568  |g|= 0.447  |ddm|= 0.17
# ...
#   HOMO = -0.211167050819515  LUMO = -0.203041740782257
# cycle= 389 E= -56.999309468764  delta_E= 0.0199  |g|= 0.316  |ddm|= 0.222
#   HOMO = -0.210144096586368  LUMO = -0.202267565231109
# cycle= 390 E= -57.0178832042953  delta_E= -0.0186  |g|= 0.272  |ddm|= 0.132
#   HOMO = -0.205641087961715  LUMO = -0.201587089429242
# cycle= 391 E= -57.0592439426015  delta_E= -0.0414  |g|= 0.111  |ddm|= 0.762
#   HOMO = -0.203014027954336  LUMO = -0.201447088235965
# cycle= 392 E= -57.0520229805517  delta_E= 0.00722  |g|= 0.154  |ddm|= 0.814
#   HOMO = -0.203010589657989  LUMO = -0.201326122111757
# cycle= 393 E= -57.0511934731329  delta_E= 0.00083  |g|= 0.157  |ddm|= 0.216
#   HOMO = -0.200089477763847  LUMO = -0.192223411479786
# cycle= 394 E= -57.0248793606693  delta_E= 0.0263  |g|= 0.151  |ddm|= 2.02
#   HOMO = -0.203486045238997  LUMO = -0.194887967336589
# cycle= 395 E= -57.0430592976951  delta_E= -0.0182  |g|= 0.123  |ddm|= 1.84
#   HOMO = -0.204304983733018  LUMO = -0.200616043009372
# cycle= 396 E= -57.0264387463538  delta_E= 0.0166  |g|= 0.128  |ddm|= 1.73
#   HOMO = -0.205468873748394  LUMO = -0.203140705775967
# cycle= 397 E= -57.0564887721615  delta_E= -0.0301  |g|= 0.0864  |ddm|= 1.66
#   HOMO = -0.203725730679555  LUMO = -0.202546124108024
# cycle= 398 E= -57.0579150870156  delta_E= -0.00143  |g|= 0.0821  |ddm|= 1.63
#   HOMO = -0.19682353057283  LUMO = -0.19313564943905
# cycle= 399 E= -57.0616688405414  delta_E= -0.00375  |g|= 0.0852  |ddm|= 1.92
#
# WARN: HOMO -0.203902439338699 == LUMO -0.203405547702855
#
# cycle= 400 E= -57.0505505804902  delta_E= 0.0111  |g|= 0.16  |ddm|= 1.39
#
# WARN: HOMO -0.203857546410895 == LUMO -0.203386989108769
#
# cycle= 401 E= -57.0465935086236  delta_E= 0.00396  |g|= 0.177  |ddm|=  0.2
#
# WARN: HOMO -0.204139444440003 == LUMO -0.203208836359766
#
# cycle= 402 E= -57.0463860531619  delta_E= 0.000207  |g|= 0.177  |ddm|= 0.0384
#
# WARN: HOMO -0.203881598235291 == LUMO -0.203059723586573
#
# cycle= 403 E= -57.0501243436089  delta_E= -0.00374  |g|= 0.162  |ddm|= 0.101
#   HOMO = -0.206872217024297  LUMO = -0.204337870538372
# cycle= 404 E= -57.0131152351574  delta_E= 0.037  |g|= 0.281  |ddm|= 0.685
#   HOMO = -0.200100522617411  LUMO = -0.194364331769688
# cycle= 405 E= -57.0246012674693  delta_E= -0.0115  |g|= 0.15  |ddm|= 2.09
#   HOMO = -0.20182874742492  LUMO = -0.200152396749844
# cycle= 406 E= -57.0297684437655  delta_E= -0.00517  |g|= 0.131  |ddm|= 1.38
#   HOMO = -0.208545169510517  LUMO = -0.198352603833697
# cycle= 407 E= -57.0578311957909  delta_E= -0.0281  |g|= 0.0991  |ddm|= 1.82
#   HOMO = -0.207984175675723  LUMO = -0.199110975170922
# cycle= 408 E= -57.0552264074481  delta_E= 0.0026  |g|= 0.142  |ddm|= 1.81
#   HOMO = -0.200924791974269  LUMO = -0.198645782434582
# cycle= 409 E= -57.0512484087977  delta_E= 0.00398  |g|= 0.103  |ddm|= 1.31
#   HOMO = -0.208284615654926  LUMO = -0.200740385652082
# cycle= 410 E= -57.038520560369  delta_E= 0.0127  |g|= 0.21  |ddm|= 1.86
#   HOMO = -0.207031048497131  LUMO = -0.20314649880287
# cycle= 411 E= -57.0359351981054  delta_E= 0.00259  |g|= 0.217  |ddm|= 0.0518
#   HOMO = -0.217147061516536  LUMO = -0.201807497354851
# cycle= 412 E= -56.9171640864534  delta_E= 0.119  |g|= 0.459  |ddm|= 0.817
#   HOMO = -0.217704214538901  LUMO = -0.20148365130016
# cycle= 413 E= -56.9140537455195  delta_E= 0.00311  |g|= 0.464  |ddm|= 0.0124
#   HOMO = -0.210874602275719  LUMO = -0.20052352738192
# cycle= 414 E= -56.9759406804267  delta_E= -0.0619  |g|= 0.364  |ddm|= 0.243
#   HOMO = -0.202903746131655  LUMO = -0.19075865459593
# cycle= 415 E= -57.0267650421654  delta_E= -0.0508  |g|= 0.154  |ddm|= 2.04
#   HOMO = -0.209455268917519  LUMO = -0.200246543002078
# cycle= 416 E= -57.0479674110686  delta_E= -0.0212  |g|= 0.176  |ddm|= 1.95
#   HOMO = -0.211583601214748  LUMO = -0.20295478720751
# cycle= 417 E= -57.0161896913677  delta_E= 0.0318  |g|= 0.277  |ddm|= 0.451
#   HOMO = -0.199287411520965  LUMO = -0.187226836413702
# cycle= 418 E= -57.03364070181  delta_E= -0.0175  |g|= 0.151  |ddm|= 2.07
#   HOMO = -0.207552481288614  LUMO = -0.203018997049062
# cycle= 419 E= -57.0216607735667  delta_E= 0.012  |g|= 0.261  |ddm|= 1.79
#   HOMO = -0.205314838447138  LUMO = -0.200863451731493
# cycle= 420 E= -57.0587237607265  delta_E= -0.0371  |g|= 0.0894  |ddm|=  1.8
#   HOMO = -0.204044972379486  LUMO = -0.201910763283569
# cycle= 421 E= -57.02641210141  delta_E= 0.0323  |g|= 0.133  |ddm|= 1.92
#   HOMO = -0.203304528235589  LUMO = -0.201920301622841
# cycle= 422 E= -57.0260282326438  delta_E= 0.000384  |g|= 0.133  |ddm|= 0.126
#   HOMO = -0.201356602047906  LUMO = -0.197042928228859
# cycle= 423 E= -57.0369397410501  delta_E= -0.0109  |g|= 0.125  |ddm|= 1.14
#   HOMO = -0.197884657719164  LUMO = -0.196140623905263
# cycle= 424 E= -57.029382588417  delta_E= 0.00756  |g|= 0.141  |ddm|= 1.57
#   HOMO = -0.206383692733501  LUMO = -0.199972625920934
# cycle= 425 E= -57.0429032455319  delta_E= -0.0135  |g|= 0.197  |ddm|= 2.06
#   HOMO = -0.201565160498574  LUMO = -0.197275787539158
# cycle= 426 E= -57.0406311418545  delta_E= 0.00227  |g|= 0.123  |ddm|= 1.99
#
# WARN: HOMO -0.200085467728787 == LUMO -0.199302055789837
#
# cycle= 427 E= -57.0627699443437  delta_E= -0.0221  |g|= 0.0705  |ddm|= 0.96
#   HOMO = -0.202615306345213  LUMO = -0.198165875620236
# cycle= 428 E= -57.0589066346352  delta_E= 0.00386  |g|= 0.0841  |ddm|= 1.96
#   HOMO = -0.207364366505836  LUMO = -0.201986879256698
# cycle= 429 E= -57.0593221687737  delta_E= -0.000416  |g|= 0.111  |ddm|= 1.58
#
# WARN: HOMO -0.203234271203383 == LUMO -0.202917929529509
#
# cycle= 430 E= -57.0601045901349  delta_E= -0.000782  |g|= 0.107  |ddm|= 0.806
#
# WARN: HOMO -0.202892187227249 == LUMO -0.202849619602509
#
# cycle= 431 E= -57.0612198000239  delta_E= -0.00112  |g|= 0.0714  |ddm|= 1.84
#   HOMO = -0.201818171186683  LUMO = -0.199386216805839
# cycle= 432 E= -57.0468235750283  delta_E= 0.0144  |g|= 0.11  |ddm|= 1.97
#   HOMO = -0.204081432212295  LUMO = -0.200227104270264
# cycle= 433 E= -57.0543922109909  delta_E= -0.00757  |g|= 0.145  |ddm|=  1.5
#   HOMO = -0.203776676360087  LUMO = -0.201379077599981
# cycle= 434 E= -57.0556389780571  delta_E= -0.00125  |g|= 0.138  |ddm|= 0.449
#   HOMO = -0.199072076632058  LUMO = -0.193474331231713
# cycle= 435 E= -57.0241768555588  delta_E= 0.0315  |g|= 0.151  |ddm|= 1.79
#   HOMO = -0.202310308339345  LUMO = -0.196923090133282
# cycle= 436 E= -57.0640149083079  delta_E= -0.0398  |g|= 0.0792  |ddm|= 1.84
#
# WARN: HOMO -0.201671318080823 == LUMO -0.200733240909196
#
# cycle= 437 E= -57.0633800358984  delta_E= 0.000635  |g|= 0.0826  |ddm|=  1.4
#
# WARN: HOMO -0.200920574507203 == LUMO -0.200614775912661
#
# cycle= 438 E= -57.0640554737235  delta_E= -0.000675  |g|= 0.0725  |ddm|= 0.086
#
# WARN: HOMO -0.204975502489792 == LUMO -0.204258270163461
#
# cycle= 439 E= -57.0587759316816  delta_E= 0.00528  |g|= 0.111  |ddm|= 1.83
#
# WARN: HOMO -0.204587268201504 == LUMO -0.203712430383009
#
# cycle= 440 E= -57.055432703253  delta_E= 0.00334  |g|= 0.137  |ddm|= 0.527
#   HOMO = -0.203568394489818  LUMO = -0.192374085623828
# cycle= 441 E= -57.0315842551276  delta_E= 0.0238  |g|= 0.141  |ddm|=  1.9
#   HOMO = -0.204484154795201  LUMO = -0.202954634073815
# cycle= 442 E= -57.0524388373156  delta_E= -0.0209  |g|= 0.152  |ddm|= 1.78
#   HOMO = -0.205436460039704  LUMO = -0.202208767854805
# cycle= 443 E= -57.0543660887979  delta_E= -0.00193  |g|= 0.144  |ddm|= 0.221
#   HOMO = -0.201190920909122  LUMO = -0.198679459150171
# cycle= 444 E= -57.0438102510048  delta_E= 0.0106  |g|= 0.119  |ddm|= 1.43
#
# WARN: HOMO -0.201484184556145 == LUMO -0.200657361099259
#
# cycle= 445 E= -57.0607270514752  delta_E= -0.0169  |g|= 0.106  |ddm|= 1.32
#
# WARN: HOMO -0.199349582803174 == LUMO -0.19859652324584
#
# cycle= 446 E= -57.0244663449074  delta_E= 0.0363  |g|= 0.144  |ddm|= 1.88
#   HOMO = -0.206375598473384  LUMO = -0.1938318659518
# cycle= 447 E= -57.0538901973231  delta_E= -0.0294  |g|= 0.107  |ddm|= 1.86
#   HOMO = -0.208803834581264  LUMO = -0.204273215034759
# cycle= 448 E= -57.0088057662588  delta_E= 0.0451  |g|= 0.293  |ddm|= 1.51
#   HOMO = -0.207758410451467  LUMO = -0.203760116338604
# cycle= 449 E= -57.0218023323382  delta_E= -0.013  |g|= 0.259  |ddm|= 0.267
#   HOMO = -0.206186448407434  LUMO = -0.203057410919885
# cycle= 450 E= -57.0303585384567  delta_E= -0.00856  |g|= 0.233  |ddm|= 0.158
#   HOMO = -0.204482524113204  LUMO = -0.200080022287827
# cycle= 451 E= -57.0495591983491  delta_E= -0.0192  |g|= 0.168  |ddm|= 0.384
#   HOMO = -0.203895038877654  LUMO = -0.201000665974675
# cycle= 452 E= -57.0267708009392  delta_E= 0.0228  |g|= 0.13  |ddm|= 1.89
#   HOMO = -0.205666791176755  LUMO = -0.201920648192503
# cycle= 453 E= -57.0505525046503  delta_E= -0.0238  |g|= 0.16  |ddm|= 1.85
#   HOMO = -0.207625878261077  LUMO = -0.202264229822941
# cycle= 454 E= -57.0426858704764  delta_E= 0.00787  |g|= 0.201  |ddm|= 1.45
#   HOMO = -0.198362024944874  LUMO = -0.193257201045905
# cycle= 455 E= -57.0415669445756  delta_E= 0.00112  |g|= 0.135  |ddm|=  1.4
#   HOMO = -0.206715156632704  LUMO = -0.197289709180953
# cycle= 456 E= -57.0602884456276  delta_E= -0.0187  |g|= 0.0902  |ddm|= 1.96
#   HOMO = -0.205128378360655  LUMO = -0.201445152713611
# cycle= 457 E= -57.0463827177649  delta_E= 0.0139  |g|= 0.178  |ddm|= 1.05
#   HOMO = -0.205865021073247  LUMO = -0.201488468900288
# cycle= 458 E= -57.0442891454775  delta_E= 0.00209  |g|= 0.186  |ddm|= 0.0297
#   HOMO = -0.2046951402757  LUMO = -0.200775533523129
# cycle= 459 E= -57.0267722466352  delta_E= 0.0175  |g|= 0.13  |ddm|= 2.01
#   HOMO = -0.205015240077435  LUMO = -0.203650233678719
# cycle= 460 E= -57.0311004531884  delta_E= -0.00433  |g|= 0.122  |ddm|= 0.549
#   HOMO = -0.199107040808895  LUMO = -0.192945607802929
# cycle= 461 E= -57.0241258361399  delta_E= 0.00697  |g|= 0.157  |ddm|= 1.82
#   HOMO = -0.212328724112298  LUMO = -0.20141271813061
# cycle= 462 E= -57.0226535321954  delta_E= 0.00147  |g|= 0.266  |ddm|= 1.91
#
# WARN: HOMO -0.203656060255832 == LUMO -0.203459082654621
#
# cycle= 463 E= -57.0379416481295  delta_E= -0.0153  |g|= 0.118  |ddm|= 2.01
#   HOMO = -0.201852399307413  LUMO = -0.199825024740585
# cycle= 464 E= -57.0452549080755  delta_E= -0.00731  |g|= 0.112  |ddm|= 0.771
#   HOMO = -0.203937170954312  LUMO = -0.19954834919733
# cycle= 465 E= -57.0305390506987  delta_E= 0.0147  |g|= 0.131  |ddm|= 1.49
#   HOMO = -0.205554509018723  LUMO = -0.197936764918046
# cycle= 466 E= -57.060776209093  delta_E= -0.0302  |g|= 0.113  |ddm|= 1.97
#   HOMO = -0.20109778796139  LUMO = -0.198323028368991
# cycle= 467 E= -57.0622206462478  delta_E= -0.00144  |g|= 0.0746  |ddm|= 1.87
#   HOMO = -0.20634916081534  LUMO = -0.202458466341711
# cycle= 468 E= -57.0442874139251  delta_E= 0.0179  |g|= 0.187  |ddm|= 1.83
#   HOMO = -0.208375737558647  LUMO = -0.203114039495074
# cycle= 469 E= -57.0181402768797  delta_E= 0.0261  |g|= 0.268  |ddm|= 0.558
#   HOMO = -0.207736000623845  LUMO = -0.203024052785559
# cycle= 470 E= -57.023713954768  delta_E= -0.00557  |g|= 0.252  |ddm|= 0.0595
#   HOMO = -0.208587319535935  LUMO = -0.203980376695709
# cycle= 471 E= -57.0035495222236  delta_E= 0.0202  |g|= 0.304  |ddm|= 0.217
#   HOMO = -0.209675184410546  LUMO = -0.202405773584788
# cycle= 472 E= -57.012811464304  delta_E= -0.00926  |g|= 0.28  |ddm|= 0.215
#   HOMO = -0.20745156854563  LUMO = -0.201569665738801
# cycle= 473 E= -57.0279908647362  delta_E= -0.0152  |g|= 0.239  |ddm|= 0.244
#   HOMO = -0.186084816187566  LUMO = -0.177664872942585
# cycle= 474 E= -57.0168519677255  delta_E= 0.0111  |g|= 0.199  |ddm|= 2.09
#   HOMO = -0.20163295723225  LUMO = -0.200405185177966
# cycle= 475 E= -57.0609566397682  delta_E= -0.0441  |g|= 0.077  |ddm|= 1.37
#   HOMO = -0.200298774502182  LUMO = -0.184097375185189
# cycle= 476 E= -57.0238884438099  delta_E= 0.0371  |g|= 0.164  |ddm|= 1.93
#   HOMO = -0.203522169231124  LUMO = -0.202061926704814
# cycle= 477 E= -57.0614484089797  delta_E= -0.0376  |g|= 0.0724  |ddm|=  1.8
#   HOMO = -0.205245130067008  LUMO = -0.199660261361398
# cycle= 478 E= -57.0594099291322  delta_E= 0.00204  |g|= 0.0873  |ddm|= 1.76
#   HOMO = -0.203699255999733  LUMO = -0.200715210921506
# cycle= 479 E= -57.0512195548279  delta_E= 0.00819  |g|= 0.159  |ddm|= 1.31
#   HOMO = -0.202849592132727  LUMO = -0.201341287845841
# cycle= 480 E= -57.0542412412842  delta_E= -0.00302  |g|= 0.144  |ddm|= 0.145
#   HOMO = -0.202783258482372  LUMO = -0.201188073165577
# cycle= 481 E= -57.0548005095617  delta_E= -0.000559  |g|= 0.141  |ddm|= 0.0238
#   HOMO = -0.202445972203571  LUMO = -0.200901840832554
# cycle= 482 E= -57.0614713747536  delta_E= -0.00667  |g|= 0.0999  |ddm|= 0.603
#   HOMO = -0.202569763212786  LUMO = -0.201335398409103
# cycle= 483 E= -57.0586091817917  delta_E= 0.00286  |g|= 0.12  |ddm|= 1.02
#   HOMO = -0.199215662698027  LUMO = -0.1878828138425
# cycle= 484 E= -57.0327914731874  delta_E= 0.0258  |g|= 0.151  |ddm|= 2.01
#   HOMO = -0.201941122789529  LUMO = -0.200900729795403
# cycle= 485 E= -57.0614211795471  delta_E= -0.0286  |g|= 0.101  |ddm|= 1.94
#   HOMO = -0.199444642151487  LUMO = -0.191817453787692
# cycle= 486 E= -57.0375708106513  delta_E= 0.0239  |g|= 0.139  |ddm|=    2
#   HOMO = -0.20050363954909  LUMO = -0.199460916965361
# cycle= 487 E= -57.0634288218822  delta_E= -0.0259  |g|= 0.0693  |ddm|= 1.49
#   HOMO = -0.194598193418795  LUMO = -0.19265944859159
# cycle= 488 E= -57.0236610269338  delta_E= 0.0398  |g|= 0.156  |ddm|= 1.75
#   HOMO = -0.202260556751773  LUMO = -0.1988635650981
# cycle= 489 E= -57.0264380449721  delta_E= -0.00278  |g|= 0.136  |ddm|= 1.82
#   HOMO = -0.204866953100141  LUMO = -0.201354242424529
# cycle= 490 E= -57.061647714132  delta_E= -0.0352  |g|= 0.093  |ddm|= 1.97
#   HOMO = -0.202922689481882  LUMO = -0.20111995396194
# cycle= 491 E= -57.0572775411737  delta_E= 0.00437  |g|= 0.128  |ddm|= 0.524
#   HOMO = -0.203068846372378  LUMO = -0.2011340648587
# cycle= 492 E= -57.0559671321621  delta_E= 0.00131  |g|= 0.135  |ddm|= 0.215
#   HOMO = -0.205145121932701  LUMO = -0.202303749584467
# cycle= 493 E= -57.0476626600552  delta_E= 0.0083  |g|= 0.173  |ddm|= 0.289
#   HOMO = -0.204880410857832  LUMO = -0.202248704153836
# cycle= 494 E= -57.0419164754608  delta_E= 0.00575  |g|= 0.196  |ddm|= 0.274
#   HOMO = -0.205070255681485  LUMO = -0.202092609312078
# cycle= 495 E= -57.0441220444346  delta_E= -0.00221  |g|= 0.188  |ddm|= 0.265
#   HOMO = -0.206242541319659  LUMO = -0.195794378332348
# cycle= 496 E= -57.0558871441542  delta_E= -0.0118  |g|= 0.108  |ddm|= 1.85
#   HOMO = -0.210784367563778  LUMO = -0.203277105261616
# cycle= 497 E= -56.9978418627367  delta_E= 0.058  |g|= 0.32  |ddm|= 1.39
#   HOMO = -0.196819009659725  LUMO = -0.178481513665398
# cycle= 498 E= -57.0187961501573  delta_E= -0.021  |g|= 0.185  |ddm|=  2.1
#   HOMO = -0.201963065334899  LUMO = -0.200594240968523
# cycle= 499 E= -57.0606997388846  delta_E= -0.0419  |g|= 0.0769  |ddm|= 1.36
#   HOMO = -0.201755273130317  LUMO = -0.200701685081845
# cycle= 500 E= -57.0287608493677  delta_E= 0.0319  |g|= 0.13  |ddm|= 1.67
# SCF not converged.
# SCF energy = -57.0287608493677
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_3848/2095352612.py in <module>
#       2 geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./CdSe_1.xyz',**setting)
#       3 geo.opt_algorithm = 'lbfgs'
# ----> 4 geo.kernel()
#
# ~/ML_QC_GEOM_OPT/MQGO/main.py in kernel(self)
#     113                         QC.update_coord(coord_ml_opt)
#     114                         print('main.py 94: QC_coords1', QC.mol.atom_coords())
# --> 115                         E_QC, G_QC = QC.calc_new()
#     116                         # print('main.py 96:', E_QC)
#     117
#
# ~/ML_QC_GEOM_OPT/MQGO/QC_engine.py in calc_new(self)
#     112             self.dm0 = self.mf.make_rdm1()
#     113
# --> 114         self.check_scf_converge()
#     115
#     116         self.e_tot = self.mf.e_tot
#
# ~/ML_QC_GEOM_OPT/MQGO/QC_engine.py in check_scf_converge(self)
#     102
#     103     def check_scf_converge(self):
# --> 104         assert self.mf.converged is True, 'SCF is not converged, please modify related paramaters and rerun the calculations.'
#     105
#     106     def calc_new(self):
#
# AssertionError: SCF is not converged, please modify related paramaters and rerun the calculations.

# %%
from pyscf import gto, scf

mol = gto.Mole(atom='''
O        3.37554198       1.98306445       1.77042260
O       26.17128840       1.15953296       1.70257011
H        3.48718928       1.81771738       1.72566221
H        3.36969874       1.99171817       1.77276519
H       26.20859573       1.24129313       1.88623203
H       26.16933587       1.15525391       1.69295785''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
# Out:
# converged SCF energy = 610.156839488383
# 610.1568394883828

# %%
mol = gto.Mole(atom='''
O        3.85028343       4.33435074      -1.46283114
O       32.83434364       4.59371931      -0.64864949
H        3.22764867       0.72764750       3.29111982
H        3.15449789       0.73050176       3.44056131
H       22.91529053      -0.47107633       3.00121399
H       22.79958584      -0.56656299       2.92919549
''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
# Out:
# SCF not converged.
# SCF energy = -144.603063781376
# -144.603063781376

# %%
from pyscf import gto, scf

mol = gto.Mole(atom='''
O   3.63802      1.57110      1.76000
O  26.36198      1.57110      1.76000
H   3.95828      2.55412      1.74392
H   2.63613      1.66728      1.76493
H  26.09174      0.99418      2.56104
H  26.09550      0.99080      0.96072''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
print('111',mf.e_tot)
# Out:
# converged SCF energy = -151.950875830031
# 111 -151.9508758300306

# %%
from pyscf.data.nist import BOHR ,HARTREE2EV
print(0.00045 * HARTREE2EV/BOHR)
# Out:
# 0.023139930171428326
