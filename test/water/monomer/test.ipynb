# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine

# %%
from deepmd.calculator import DP
# Out:
# 2022-03-23 12:01:53.451068: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 12:01:53.451115: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
setting = {'basis':'6-31g', 'spin':0, 'xc':False, 'restricted':True, 'verbose':4}
geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./water.xyz',**setting)
geo.opt_algorithm = 'lbfgs'
geo.kernel()
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.10000000000 will be used
# ******** <class 'pyscf.dft.rks.RKS'> ********
# method = RKS-RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-12
# SCF conv_tol_grad = None
# SCF max_cycles = 100
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /home/jingheng/ML_QC_GEOM_OPT/test/water/monomer/tmpfd1j647b
# max_memory 4000 MB (current use 356 MB)
# XC library pyscf.dft.libxc version 5.2.0
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018)
# XC functionals = LDA,VWN
#     P. A. M. Dirac, Math. Proc. Cambridge Philos. Soc. 26, 376 (1930)
#     F. Bloch, Z. Phys. 57, 545 (1929)
#     S. H. Vosko, L. Wilk, and M. Nusair, Can. J. Phys. 58, 1200 (1980)
# small_rho_cutoff = 1e-07
# Set gradient conv threshold to 1e-06
# init E= -75.7414288534964
#   HOMO = -0.38899207769774  LUMO = -0.00634450326676841
# cycle= 1 E= -75.701659102075  delta_E= 0.0398  |g|= 0.763  |ddm|= 1.21
#   HOMO = -0.030513415435839  LUMO = 0.0846997286372559
# cycle= 2 E= -75.3654233647094  delta_E= 0.336  |g|= 1.47  |ddm|= 1.86
#   HOMO = -0.238557018644368  LUMO = 0.0109221460026886
# cycle= 3 E= -75.8169326477904  delta_E= -0.452  |g|= 0.0473  |ddm|= 1.42
#   HOMO = -0.22658263808255  LUMO = 0.0132192108369092
# cycle= 4 E= -75.8174730864361  delta_E= -0.00054  |g|= 0.00242  |ddm|= 0.0561
#   HOMO = -0.226572733007691  LUMO = 0.012832468766428
# cycle= 5 E= -75.8174743143124  delta_E= -1.23e-06  |g|= 0.000339  |ddm|= 0.00275
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29379 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29407 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29408 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29409 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29410 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29411 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29412 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29413 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29414 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29415 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29416 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29417 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29418 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29419 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29420 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29379 tid 29421 thread 15 bound to OS proc set 15
#   HOMO = -0.226641622179569  LUMO = 0.0127282422652387
# cycle= 6 E= -75.8174743580068  delta_E= -4.37e-08  |g|= 8.04e-05  |ddm|= 0.00061
#   HOMO = -0.226657230997375  LUMO = 0.0127179486425831
# cycle= 7 E= -75.817474359709  delta_E= -1.7e-09  |g|= 4e-06  |ddm|= 8.9e-05
#   HOMO = -0.226657627428679  LUMO = 0.0127179531088746
# cycle= 8 E= -75.8174743597153  delta_E= -6.34e-12  |g|= 5.8e-07  |ddm|= 6.01e-06
#   HOMO = -0.226657764949052  LUMO = 0.0127178482081177
# cycle= 9 E= -75.8174743597154  delta_E= -1.28e-13  |g|= 6.58e-08  |ddm|= 2.87e-07
#   HOMO = -0.226657794375489  LUMO = 0.0127178389403531
# Extra cycle  E= -75.8174743597154  delta_E= 4.26e-14  |g|= 1.31e-07  |ddm|= 1.38e-07
# converged SCF energy = -75.8174743597154
#
#
# ******** <class 'pyscf.grad.rks.Gradients'> for <class 'pyscf.dft.rks.RKS'> ********
# unit = Eh/Bohr
# max_memory 4000 MB (current use 367 MB)
# grid_response = False
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
# main.py 81 QC_coords0: [[6.87486144 2.96894871 3.32591798]
#  [7.48006512 4.82658729 3.29553118]
#  [4.98156373 3.15070257 3.33523433]]
#
#
# ******** <class 'pyscf.grad.rks.Gradients'> for <class 'pyscf.dft.rks.RKS'> ********
# unit = Eh/Bohr
# max_memory 4000 MB (current use 373 MB)
# grid_response = False
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-03-23 12:01:56.411563: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 12:01:56.411604: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# /home/jingheng/venv/lib/python3.9/site-packages/deepmd/utils/data_system.py:158: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (11 > 1)
#   warnings.warn("system %s required batch size is larger than the size of the dataset %s (%d > %d)" % \
# 2022-03-23 12:01:59.815928: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-23 12:01:59.819023: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-23 12:01:59.819059: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-23 12:01:59.819088: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29496 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29499 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29498 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29500 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29501 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29503 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29502 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29505 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29504 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29508 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29507 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29506 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29510 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29509 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29511 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29512 thread 15 bound to OS proc set 15
# DEEPMD INFO    training data with min nbor dist: 1.0065080572951215
# DEEPMD INFO    training data with max nbor size: [1, 2]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       3      11       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29495 thread 16 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29514 thread 18 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29515 thread 19 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29520 thread 24 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29513 thread 17 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29518 thread 22 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29517 thread 21 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29519 thread 23 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29516 thread 20 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29521 thread 25 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29523 thread 27 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29522 thread 26 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29524 thread 28 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29525 thread 29 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29526 thread 30 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29527 thread 31 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29426 thread 32 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 1000, decay_rate 0.358534, final lr will be 3.51e-08
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29494 thread 33 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29532 thread 35 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29531 thread 34 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29534 thread 37 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29533 thread 36 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29535 thread 38 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29536 thread 39 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29538 thread 41 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29540 thread 43 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29537 thread 40 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29539 thread 42 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29542 thread 45 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29541 thread 44 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29543 thread 46 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29544 thread 47 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29545 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29481 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29546 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29547 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29548 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29549 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29550 thread 54 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29551 thread 55 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29552 thread 56 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29553 thread 57 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29554 thread 58 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29555 thread 59 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29556 thread 60 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29557 thread 61 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29558 thread 62 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29559 thread 63 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29560 thread 64 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29486 thread 65 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29561 thread 66 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29562 thread 67 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29563 thread 68 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29564 thread 69 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29565 thread 70 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29566 thread 71 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29567 thread 72 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29568 thread 73 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29569 thread 74 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29570 thread 75 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29571 thread 76 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29572 thread 77 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29573 thread 78 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29574 thread 79 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29575 thread 80 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29483 thread 81 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29576 thread 82 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29577 thread 83 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29578 thread 84 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29579 thread 85 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29580 thread 86 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29581 thread 87 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29582 thread 88 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29583 thread 89 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29584 thread 90 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29585 thread 91 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29586 thread 92 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29587 thread 93 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29588 thread 94 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29589 thread 95 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29590 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29490 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29592 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29591 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29593 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29595 thread 102 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29594 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29596 thread 103 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29597 thread 104 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29598 thread 105 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29599 thread 106 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29600 thread 107 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29601 thread 108 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29602 thread 109 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29604 thread 111 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29603 thread 110 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29605 thread 112 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29489 thread 113 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29606 thread 114 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29607 thread 115 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29608 thread 116 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29609 thread 117 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29610 thread 118 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29611 thread 119 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29612 thread 120 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29613 thread 121 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29614 thread 122 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29615 thread 123 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29616 thread 124 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29617 thread 125 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29618 thread 126 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29619 thread 127 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29620 thread 128 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29487 thread 129 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29621 thread 130 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29622 thread 131 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29623 thread 132 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29624 thread 133 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29625 thread 134 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29626 thread 135 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29627 thread 136 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29628 thread 137 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29629 thread 138 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29630 thread 139 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29631 thread 140 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29632 thread 141 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29633 thread 142 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29634 thread 143 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29635 thread 144 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29485 thread 145 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29636 thread 146 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29637 thread 147 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29638 thread 148 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29639 thread 149 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29640 thread 150 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29641 thread 151 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29642 thread 152 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29643 thread 153 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29644 thread 154 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29645 thread 155 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29646 thread 156 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29647 thread 157 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29648 thread 158 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29649 thread 159 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29650 thread 160 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29492 thread 161 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29651 thread 162 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29652 thread 163 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29653 thread 164 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29654 thread 165 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29655 thread 166 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29656 thread 167 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29657 thread 168 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29658 thread 169 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29659 thread 170 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29660 thread 171 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29661 thread 172 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29662 thread 173 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29663 thread 174 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29664 thread 175 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29665 thread 176 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29491 thread 177 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29666 thread 178 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29667 thread 179 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29668 thread 180 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29669 thread 181 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29670 thread 182 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29671 thread 183 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29672 thread 184 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29673 thread 185 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29674 thread 186 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29675 thread 187 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29676 thread 188 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29677 thread 189 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29678 thread 190 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29679 thread 191 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29680 thread 192 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29482 thread 193 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29684 thread 194 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29685 thread 195 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29686 thread 196 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29687 thread 197 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29688 thread 198 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29689 thread 199 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29690 thread 200 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29691 thread 201 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29692 thread 202 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29693 thread 203 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29694 thread 204 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29695 thread 205 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29696 thread 206 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29697 thread 207 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29698 thread 208 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29488 thread 209 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29699 thread 210 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29700 thread 211 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29701 thread 212 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29702 thread 213 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29703 thread 214 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29704 thread 215 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29705 thread 216 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29706 thread 217 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29707 thread 218 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29708 thread 219 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29709 thread 220 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29710 thread 221 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29711 thread 222 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29712 thread 223 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29713 thread 224 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29484 thread 225 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29714 thread 226 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29715 thread 227 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29716 thread 228 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29717 thread 229 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29718 thread 230 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29719 thread 231 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29720 thread 232 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29721 thread 233 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29722 thread 234 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29723 thread 235 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29724 thread 236 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29725 thread 237 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29726 thread 238 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29727 thread 239 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29728 thread 240 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29493 thread 241 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29729 thread 242 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29730 thread 243 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29731 thread 244 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29732 thread 245 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29733 thread 246 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29734 thread 247 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29735 thread 248 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29736 thread 249 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29737 thread 250 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29738 thread 251 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29739 thread 252 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29740 thread 253 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29741 thread 254 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29742 thread 255 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 29426 tid 29743 thread 256 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 1.60 s, testing time 0.00 s
# DEEPMD INFO    batch     200 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    batch     300 training time 0.98 s, testing time 0.00 s
# DEEPMD INFO    batch     400 training time 0.98 s, testing time 0.00 s
# DEEPMD INFO    batch     500 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    batch     600 training time 0.98 s, testing time 0.00 s
# DEEPMD INFO    batch     700 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    batch     800 training time 0.96 s, testing time 0.01 s
# DEEPMD INFO    batch     900 training time 0.99 s, testing time 0.00 s
# DEEPMD INFO    batch    1000 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    1200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    2200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    2300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    2500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    2600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    2700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    3200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3500 training time 0.88 s, testing time 0.00 s
# DEEPMD INFO    batch    3600 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    3700 training time 0.89 s, testing time 0.00 s
# DEEPMD INFO    batch    3800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    4100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    4200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    4300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4600 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    4700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    5100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    5200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5500 training time 0.88 s, testing time 0.00 s
# DEEPMD INFO    batch    5600 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    5700 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5800 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    5900 training time 0.88 s, testing time 0.00 s
# DEEPMD INFO    batch    6000 training time 0.88 s, testing time 0.00 s
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    6100 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    6200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    6300 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    6400 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    6500 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    6600 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    6700 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    6800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6900 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    7000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    7100 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch    7200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    7300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    7400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8000 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    8100 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    8200 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch    8300 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    8400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    8500 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    8600 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    8700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    8900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    9100 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    9200 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch    9300 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    9400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    9500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9700 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    9800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    9900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   10000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    finished training
# DEEPMD INFO    wall time: 108.332 s
# 2022-03-23 12:03:50.329332: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 12:03:50.329375: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-23 12:03:52.426655: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-23 12:03:52.426704: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-23 12:03:52.426735: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-23 12:03:52.426987: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    1150 ops in the final graph.
# 2022-03-23 12:03:53.304486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 12:03:53.304534: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# ...
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-23 13:12:05.907719: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-23 13:12:05.907775: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-23 13:12:05.907805: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-23 13:12:05.908112: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    1150 ops in the final graph.
# 2022-03-23 13:12:06.916132: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 13:12:06.916175: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-23 13:12:08.509080: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-23 13:12:08.509123: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-23 13:12:08.509151: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-23 13:12:08.509387: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 1: compress the model
# DEEPMD WARNING Switch to serial execution due to lack of horovod module.
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    training data with lower boundary: -0.12121347601783264
# DEEPMD INFO    training data with upper boundary: 11.271750248276033
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11316 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11390 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11392 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11391 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11394 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11393 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11395 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11396 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11397 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11400 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11398 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11399 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11402 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11401 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11403 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 11316 tid 11404 thread 15 bound to OS proc set 15
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    finished compressing
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 2: freeze the model
# INFO:tensorflow:Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    786 ops in the final graph.
# optimizer.py 77: [[3.6084913  1.60350446 1.75972225]
#  [3.99639924 2.50774015 1.74434363]
#  [2.62753944 1.68125539 1.76478412]]
#        Step     Time          Energy          fmax
# LBFGS:    0 13:12:14    -2063.067198         0.004405
# LBFGS:    1 13:12:14    -2063.067199         0.008876
# LBFGS:    2 13:12:14    -2063.067198         0.000432
# main.py 94: QC_coords1 [[6.81913549 3.03007898 3.32539414]
#  [7.55213706 4.7390356  3.29633016]
#  [4.9652177  3.17712399 3.33495919]]
#
#
# ******** <class 'pyscf.dft.rks.RKS'> ********
# method = RKS-RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-12
# SCF conv_tol_grad = None
# SCF max_cycles = 100
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /home/jingheng/ML_QC_GEOM_OPT/test/water/monomer/tmpkxkpg4j5
# max_memory 4000 MB (current use 1842 MB)
# XC library pyscf.dft.libxc version 5.2.0
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018)
# XC functionals = LDA,VWN
#     P. A. M. Dirac, Math. Proc. Cambridge Philos. Soc. 26, 376 (1930)
#     F. Bloch, Z. Phys. 57, 545 (1929)
#     S. H. Vosko, L. Wilk, and M. Nusair, Can. J. Phys. 58, 1200 (1980)
# small_rho_cutoff = 1e-07
# Set gradient conv threshold to 1e-06
# init E= -75.7756234613802
#   HOMO = -0.396284189615671  LUMO = 0.0026043710092822
# cycle= 1 E= -75.707192423525  delta_E= 0.0684  |g|= 0.766  |ddm|= 1.23
#   HOMO = -0.0352614453450429  LUMO = 0.0916845716216772
# cycle= 2 E= -75.4322752702087  delta_E= 0.275  |g|= 1.39  |ddm|=  1.7
#   HOMO = -0.236146803316096  LUMO = 0.0241485981643488
# cycle= 3 E= -75.8196548918614  delta_E= -0.387  |g|= 0.0314  |ddm|= 1.26
#   HOMO = -0.226528959263785  LUMO = 0.0265198266681863
# cycle= 4 E= -75.8198997636499  delta_E= -0.000245  |g|= 0.00154  |ddm|= 0.0402
#   HOMO = -0.22656881216999  LUMO = 0.026058149025265
# cycle= 5 E= -75.8199002081802  delta_E= -4.45e-07  |g|= 0.000301  |ddm|= 0.00151
#   HOMO = -0.226656705594348  LUMO = 0.0259817303690267
# cycle= 6 E= -75.8199002243586  delta_E= -1.62e-08  |g|= 1.48e-05  |ddm|= 0.000183
#   HOMO = -0.226659464409583  LUMO = 0.0259805296701564
# cycle= 7 E= -75.8199002244266  delta_E= -6.8e-11  |g|= 2.31e-06  |ddm|= 1.79e-05
#   HOMO = -0.226659957710746  LUMO = 0.0259802224354091
# cycle= 8 E= -75.8199002244274  delta_E= -8.67e-13  |g|= 1.44e-07  |ddm|= 1.24e-06
#   HOMO = -0.226660022542911  LUMO = 0.0259802022906975
# Extra cycle  E= -75.8199002244275  delta_E= -4.26e-14  |g|= 2.66e-07  |ddm|= 2.77e-07
# converged SCF energy = -75.8199002244275
#
#
# ******** <class 'pyscf.grad.rks.Gradients'> for <class 'pyscf.dft.rks.RKS'> ********
# unit = Eh/Bohr
# max_memory 4000 MB (current use 1842 MB)
# grid_response = False
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O    -0.0002569152     0.0004391909    -0.0000062841
# 1 H     0.0001062777    -0.0002330589     0.0000023643
# 2 H     0.0001498255    -0.0002028554     0.0000019231
# ----------------------------------------------
#
#
# ******** <class 'pyscf.grad.rks.Gradients'> for <class 'pyscf.dft.rks.RKS'> ********
# unit = Eh/Bohr
# max_memory 4000 MB (current use 1842 MB)
# grid_response = False
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O    -0.0002569152     0.0004391909    -0.0000062841
# 1 H     0.0001062777    -0.0002330589     0.0000023643
# 2 H     0.0001498255    -0.0002028554     0.0000019231
# ----------------------------------------------

# %%
from pyscf import gto, scf
from pyscf.geomopt.berny_solver import optimize

mol = gto.M(atom='''
O   3.63802      1.57110      1.76000
H   3.95828      2.55412      1.74392
H   2.63613      1.66728      1.76493
''', basis='6-31g')
mf = scf.RHF(mol)

# #
# # geometry optimization for HF.  There are two entries to invoke the berny
# # geometry optimization.
# #
# # method 1: import the optimize function from pyscf.geomopt.berny_solver
# mol_eq = optimize(mf)
# print(mol_eq.atom_coords())

# method 2: create the optimizer from Gradients class
mol_eq = mf.Gradients().optimizer(solver='berny').kernel()
# Out:
# INFO:pyscf.geomopt.berny_solver.139900527602608:0 Internal coordinates:
# INFO:pyscf.geomopt.berny_solver.139900527602608:0 * Number of fragments: 1
# INFO:pyscf.geomopt.berny_solver.139900527602608:0 * Number of internal coordinates: 3
# INFO:pyscf.geomopt.berny_solver.139900527602608:0 * Number of strong bonds: 2
# INFO:pyscf.geomopt.berny_solver.139900527602608:0 * Number of strong angles: 1
# Geometry optimization cycle 1
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   3.638020   1.571100   1.760000    0.000000  0.000000  0.000000
#    H   3.958280   2.554120   1.743920    0.000000  0.000000  0.000000
#    H   2.636130   1.667280   1.764930    0.000000  0.000000  0.000000
# converged SCF energy = -75.9755790262162
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0337331228    -0.0786141018     0.0009124231
# 1 H     0.0107641654     0.0643378542    -0.0009882438
# 2 H    -0.0444972882     0.0142762476     0.0000758207
# ----------------------------------------------
# cycle 1: E = -75.9755790262  dE = -75.9756  norm(grad) = 0.117299
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 Energy: -75.9755790262
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 Pure RFO step was performed:
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Lowest eigenvalue: 0.176
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * lambda: -0.0144
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 Quadratic step: RMS: 0.108, max: 0.13
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Predicted energy change: -0.00744
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 Total step: RMS: 0.108, max: 0.13
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 Perfect transformation to cartesians in 5 iterations
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * RMS(dcart): 1.76e-07, RMS(dq): 5.21e-07
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Gradient RMS: 0.0469 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Gradient maximum: 0.0645 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Step RMS: 0.108 > 0.0012 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:1 * Step maximum: 0.13 > 0.0018 => no
# Geometry optimization cycle 2
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   3.617013   1.616621   1.759481   -0.021007  0.045521 -0.000519
#    H   3.956564   2.520002   1.744419   -0.001716 -0.034118  0.000499
#    H   2.658853   1.655877   1.764950    0.022723 -0.011403  0.000020
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -75.9848345889767
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0068864204    -0.0199395638     0.0002419344
# 1 H     0.0005927092     0.0149086769    -0.0002170315
# 2 H    -0.0074791296     0.0050308869    -0.0000249028
# ----------------------------------------------
# cycle 2: E = -75.984834589  dE = -0.00925556  norm(grad) = 0.0273675
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Energy: -75.984834589
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Change: RMS: 0.0283, max: 0.0523
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Trust update: Fletcher's parameter: 1.24
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Energies: -75.984835, -75.975579
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Derivatives: 0.00338, 0.0144
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Quartic interpolation was performed: t = -0.242
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Interpolated energy: -75.98525
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Pure RFO step was performed:
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Lowest eigenvalue: 0.159
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * lambda: -0.000246
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Quadratic step: RMS: 0.0224, max: 0.038
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Predicted energy change: -0.000123
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Total step: RMS: 0.0439, max: 0.0621
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Perfect transformation to cartesians in 4 iterations
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * RMS(dcart): 2.75e-07, RMS(dq): 8.26e-07
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Gradient RMS: 0.0105 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Gradient maximum: 0.0142 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Step RMS: 0.0439 > 0.0012 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:2 * Step maximum: 0.0621 > 0.0018 => no
# Geometry optimization cycle 3
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   3.607550   1.636964   1.759249   -0.009463  0.020343 -0.000231
#    H   3.965366   2.511130   1.744490    0.008802 -0.008872  0.000072
#    H   2.659514   1.644406   1.765110    0.000661 -0.011470  0.000160
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -75.9853308623482
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0004089468     0.0053194688    -0.0000786805
# 1 H    -0.0018855518    -0.0051157175     0.0000850594
# 2 H     0.0014766050    -0.0002037513    -0.0000063789
# ----------------------------------------------
# cycle 3: E = -75.9853308623  dE = -0.000496273  norm(grad) = 0.00777336
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Energy: -75.9853308623
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Change: RMS: 0.036, max: 0.0941
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Trust update: Fletcher's parameter: 4.03
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Energies: -75.985331, -75.984835
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Derivatives: -0.000263, 0.00124
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Quartic interpolation was performed: t = 0.17
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Interpolated energy: -75.985353
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Pure RFO step was performed:
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Lowest eigenvalue: 0.156
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * lambda: -1.66e-05
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Quadratic step: RMS: 0.00471, max: 0.00717
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Predicted energy change: -8.28e-06
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Total step: RMS: 0.00659, max: 0.0105
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Perfect transformation to cartesians in 3 iterations
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * RMS(dcart): 6.58e-09, RMS(dq): 2.02e-08
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Gradient RMS: 0.00327 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Gradient maximum: 0.00545 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Step RMS: 0.00659 > 0.0012 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:3 * Step maximum: 0.0105 > 0.0018 => no
# Geometry optimization cycle 4
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   3.607639   1.634349   1.759286    0.000089 -0.002615  0.000037
#    H   3.966766   2.513957   1.744441    0.001400  0.002827 -0.000049
#    H   2.658025   1.644194   1.765122   -0.001489 -0.000212  0.000012
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -75.9853586157939
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0003038805    -0.0004427505     0.0000082472
# 1 H     0.0004033150     0.0005915941    -0.0000110026
# 2 H    -0.0000994345    -0.0001488436     0.0000027554
# ----------------------------------------------
# cycle 4: E = -75.9853586158  dE = -2.77534e-05  norm(grad) = 0.000912829
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Energy: -75.9853586158
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Change: RMS: 0.0269, max: 0.0713
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Trust update: Fletcher's parameter: 3.35
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Energies: -75.985359, -75.985331
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Derivatives: -6.7e-06, 6.26e-05
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Quartic interpolation was performed: t = 0.0983
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Interpolated energy: -75.985359
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Pure RFO step was performed:
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Lowest eigenvalue: 0.151
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * lambda: -5.13e-07
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Quadratic step: RMS: 0.00104, max: 0.00179
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Predicted energy change: -2.56e-07
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Total step: RMS: 0.00105, max: 0.00146
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Perfect transformation to cartesians in 2 iterations
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * RMS(dcart): 1.05e-07, RMS(dq): 5.18e-07
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Gradient RMS: 0.000437 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Gradient maximum: 0.0007 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Step RMS: 0.00105 < 0.0012 => OK
# INFO:pyscf.geomopt.berny_solver.139900527602608:4 * Step maximum: 0.00146 < 0.0018 => OK
# Geometry optimization cycle 5
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   3.607939   1.634230   1.759286    0.000300 -0.000119 -0.000000
#    H   3.966113   2.513607   1.744450   -0.000653 -0.000350  0.000009
#    H   2.658378   1.644663   1.765114    0.000353  0.000469 -0.000009
# converged SCF energy = -75.9853591732738
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0000160378    -0.0000262336     0.0000002744
# 1 H    -0.0000164745     0.0000079440    -0.0000000100
# 2 H     0.0000004367     0.0000182896    -0.0000002644
# ----------------------------------------------
# cycle 5: E = -75.9853591733  dE = -5.5748e-07  norm(grad) = 4.01842e-05
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Energy: -75.9853591733
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Change: RMS: 0.00949, max: 0.0176
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Trust update: Fletcher's parameter: 2.17
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Energies: -75.985359, -75.985359
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Derivatives: -4.66e-08, 1.16e-06
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Cubic interpolation was performed: t = 0.0385
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Interpolated energy: -75.985359
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Pure RFO step was performed:
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Lowest eigenvalue: 0.161
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * lambda: -4.81e-09
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Quadratic step: RMS: 9.1e-05, max: 0.000145
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Predicted energy change: -2.41e-09
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Total step: RMS: 0.000117, max: 0.000201
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Perfect transformation to cartesians in 2 iterations
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * RMS(dcart): 2.15e-09, RMS(dq): 7.46e-09
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Gradient RMS: 1.89e-05 < 0.00015 => OK
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Gradient maximum: 3.28e-05 < 0.00045 => OK
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Step RMS: 0.000117 < 0.0012 => OK
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * Step maximum: 0.000201 < 0.0018 => OK
# INFO:pyscf.geomopt.berny_solver.139900527602608:5 * All criteria matched

# %%
from pyscf.data.nist import HARTREE2EV
print(-75.9853591733*HARTREE2EV)
# Out:
# -2067.6669403330143
