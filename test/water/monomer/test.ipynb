# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine

# %%
from deepmd.calculator import DP
# Out:
# 2022-03-22 16:45:47.382747: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:45:47.382796: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
setting = {'basis':'6-31g', 'spin':0, 'xc':False, 'restricted':True, 'verbose':3}
geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./water.xyz',**setting)
geo.opt_algorithm = 'lbfgs'
geo.kernel()
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.10000000000 will be used
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 255 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6493 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6494 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6495 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6496 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6497 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6498 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6499 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6500 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6501 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6502 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6504 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6503 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6505 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6506 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 255 tid 6507 thread 15 bound to OS proc set 15
# converged SCF energy = -75.8174743597154
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
# main.py 81 QC_coords0: [[6.87486144 2.96894871 3.32591798]
#  [7.48006512 4.82658729 3.29553118]
#  [4.98156373 3.15070257 3.33523433]]
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-03-22 16:46:54.495727: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:46:54.495767: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# /home/jingheng/venv/lib/python3.9/site-packages/deepmd/utils/data_system.py:158: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (11 > 1)
#   warnings.warn("system %s required batch size is larger than the size of the dataset %s (%d > %d)" % \
# 2022-03-22 16:46:58.082706: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 16:46:58.085562: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-22 16:46:58.085593: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-22 16:46:58.085619: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6576 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6578 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6581 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6580 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6579 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6582 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6583 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6584 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6585 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6586 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6587 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6588 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6589 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6590 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6591 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6592 thread 15 bound to OS proc set 15
# DEEPMD INFO    training data with min nbor dist: 1.0065080572951215
# DEEPMD INFO    training data with max nbor size: [1, 2]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       3      11       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6575 thread 16 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6594 thread 18 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6593 thread 17 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6596 thread 20 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6595 thread 19 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6597 thread 21 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6599 thread 23 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6598 thread 22 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6600 thread 24 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6601 thread 25 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6603 thread 27 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6602 thread 26 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6604 thread 28 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6605 thread 29 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6606 thread 30 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6607 thread 31 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6509 thread 32 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 1000, decay_rate 0.358534, final lr will be 3.51e-08
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6573 thread 33 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6608 thread 34 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6609 thread 35 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6610 thread 36 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6611 thread 37 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6612 thread 38 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6613 thread 39 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6614 thread 40 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6615 thread 41 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6617 thread 43 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6616 thread 42 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6618 thread 44 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6619 thread 45 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6620 thread 46 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6621 thread 47 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6622 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6566 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6623 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6624 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6625 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6629 thread 56 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6626 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6628 thread 55 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6630 thread 57 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6631 thread 58 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6632 thread 59 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6627 thread 54 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6633 thread 60 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6634 thread 61 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6635 thread 62 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6636 thread 63 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6637 thread 64 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6563 thread 65 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6638 thread 66 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6639 thread 67 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6640 thread 68 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6641 thread 69 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6642 thread 70 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6643 thread 71 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6644 thread 72 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6645 thread 73 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6646 thread 74 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6647 thread 75 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6648 thread 76 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6649 thread 77 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6650 thread 78 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6651 thread 79 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6652 thread 80 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6567 thread 81 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6653 thread 82 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6654 thread 83 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6655 thread 84 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6656 thread 85 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6657 thread 86 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6658 thread 87 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6659 thread 88 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6660 thread 89 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6661 thread 90 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6662 thread 91 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6663 thread 92 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6664 thread 93 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6665 thread 94 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6666 thread 95 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6667 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6571 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6668 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6669 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6670 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6671 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6672 thread 102 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6673 thread 103 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6674 thread 104 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6675 thread 105 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6676 thread 106 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6677 thread 107 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6678 thread 108 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6679 thread 109 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6680 thread 110 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6681 thread 111 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6682 thread 112 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6574 thread 113 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6683 thread 114 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6684 thread 115 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6685 thread 116 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6686 thread 117 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6687 thread 118 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6688 thread 119 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6689 thread 120 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6690 thread 121 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6691 thread 122 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6692 thread 123 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6693 thread 124 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6694 thread 125 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6695 thread 126 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6696 thread 127 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6697 thread 128 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6570 thread 129 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6698 thread 130 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6699 thread 131 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6700 thread 132 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6701 thread 133 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6702 thread 134 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6703 thread 135 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6704 thread 136 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6705 thread 137 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6706 thread 138 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6707 thread 139 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6708 thread 140 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6709 thread 141 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6710 thread 142 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6711 thread 143 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6712 thread 144 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6562 thread 145 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6713 thread 146 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6714 thread 147 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6715 thread 148 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6716 thread 149 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6717 thread 150 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6718 thread 151 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6719 thread 152 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6720 thread 153 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6721 thread 154 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6722 thread 155 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6723 thread 156 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6724 thread 157 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6725 thread 158 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6726 thread 159 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6727 thread 160 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6564 thread 161 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6728 thread 162 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6729 thread 163 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6730 thread 164 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6731 thread 165 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6732 thread 166 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6733 thread 167 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6734 thread 168 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6735 thread 169 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6736 thread 170 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6737 thread 171 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6738 thread 172 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6739 thread 173 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6740 thread 174 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6741 thread 175 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6742 thread 176 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6561 thread 177 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6743 thread 178 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6744 thread 179 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6745 thread 180 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6746 thread 181 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6747 thread 182 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6748 thread 183 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6749 thread 184 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6750 thread 185 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6751 thread 186 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6752 thread 187 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6753 thread 188 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6754 thread 189 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6755 thread 190 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6756 thread 191 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6757 thread 192 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6569 thread 193 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6758 thread 194 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6759 thread 195 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6760 thread 196 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6761 thread 197 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6762 thread 198 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6763 thread 199 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6764 thread 200 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6765 thread 201 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6766 thread 202 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6767 thread 203 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6768 thread 204 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6769 thread 205 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6770 thread 206 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6771 thread 207 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6772 thread 208 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6565 thread 209 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6773 thread 210 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6774 thread 211 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6775 thread 212 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6776 thread 213 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6777 thread 214 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6778 thread 215 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6779 thread 216 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6780 thread 217 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6781 thread 218 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6782 thread 219 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6783 thread 220 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6784 thread 221 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6785 thread 222 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6786 thread 223 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6787 thread 224 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6572 thread 225 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6788 thread 226 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6789 thread 227 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6790 thread 228 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6791 thread 229 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6792 thread 230 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6793 thread 231 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6794 thread 232 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6795 thread 233 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6796 thread 234 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6797 thread 235 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6798 thread 236 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6799 thread 237 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6800 thread 238 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6801 thread 239 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6802 thread 240 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6568 thread 241 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6803 thread 242 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6804 thread 243 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6805 thread 244 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6806 thread 245 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6807 thread 246 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6808 thread 247 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6809 thread 248 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6810 thread 249 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6811 thread 250 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6812 thread 251 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6813 thread 252 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6814 thread 253 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6815 thread 254 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6816 thread 255 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 6509 tid 6817 thread 256 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 1.54 s, testing time 0.00 s
# DEEPMD INFO    batch     200 training time 0.93 s, testing time 0.00 s
# DEEPMD INFO    batch     300 training time 0.95 s, testing time 0.00 s
# DEEPMD INFO    batch     400 training time 0.99 s, testing time 0.00 s
# DEEPMD INFO    batch     500 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    batch     600 training time 0.95 s, testing time 0.00 s
# DEEPMD INFO    batch     700 training time 0.94 s, testing time 0.01 s
# DEEPMD INFO    batch     800 training time 0.95 s, testing time 0.00 s
# DEEPMD INFO    batch     900 training time 0.96 s, testing time 0.01 s
# DEEPMD INFO    batch    1000 training time 0.98 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 0.88 s, testing time 0.00 s
# DEEPMD INFO    batch    1200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    1300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2000 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    2200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    2300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3000 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    3200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    3300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    4100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    4200 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    4300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    5100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    5200 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    5300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5500 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6000 training time 0.85 s, testing time 0.00 s
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    6100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    6200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    6600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    7100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    7200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    7800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    7900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    8100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    8200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    9100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    9200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    9700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    9900 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   10000 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    finished training
# DEEPMD INFO    wall time: 106.822 s
# 2022-03-22 16:48:47.136559: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:48:47.136598: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-22 16:48:49.190728: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-22 16:48:49.190773: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-22 16:48:49.190802: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-22 16:48:49.191088: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/deepmd/entrypoints/freeze.py:241: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/framework/convert_to_constants.py:925: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    1150 ops in the final graph.
# 2022-03-22 16:48:50.174293: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 16:48:50.174334: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-22 16:48:51.834746: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-22 16:48:51.834788: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-22 16:48:51.834816: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# 2022-03-22 16:48:51.835046: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 1: compress the model
# DEEPMD WARNING Switch to serial execution due to lack of horovod module.
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    training data with lower boundary: -0.12125570974870829
# DEEPMD INFO    training data with upper boundary: 10.127023945499651
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# ...
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24722 thread 71 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24724 thread 73 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24723 thread 72 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24725 thread 74 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24726 thread 75 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24728 thread 77 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24727 thread 76 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24729 thread 78 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24730 thread 79 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24731 thread 80 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24638 thread 81 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24732 thread 82 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24733 thread 83 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24734 thread 84 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24735 thread 85 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24736 thread 86 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24737 thread 87 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24738 thread 88 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24739 thread 89 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24740 thread 90 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24741 thread 91 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24742 thread 92 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24743 thread 93 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24744 thread 94 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24745 thread 95 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24746 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24636 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24747 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24748 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24749 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24750 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24751 thread 102 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24752 thread 103 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24753 thread 104 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24754 thread 105 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24755 thread 106 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24756 thread 107 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24757 thread 108 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24758 thread 109 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24759 thread 110 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24760 thread 111 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24761 thread 112 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24646 thread 113 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24762 thread 114 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24763 thread 115 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24764 thread 116 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24765 thread 117 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24766 thread 118 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24767 thread 119 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24768 thread 120 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24769 thread 121 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24770 thread 122 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24771 thread 123 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24772 thread 124 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24773 thread 125 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24774 thread 126 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24775 thread 127 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24776 thread 128 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24643 thread 129 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24777 thread 130 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24778 thread 131 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24779 thread 132 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24780 thread 133 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24781 thread 134 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24782 thread 135 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24783 thread 136 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24784 thread 137 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24785 thread 138 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24786 thread 139 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24787 thread 140 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24788 thread 141 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24789 thread 142 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24790 thread 143 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24791 thread 144 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24640 thread 145 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24792 thread 146 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24793 thread 147 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24794 thread 148 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24795 thread 149 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24796 thread 150 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24797 thread 151 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24798 thread 152 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24799 thread 153 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24800 thread 154 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24801 thread 155 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24802 thread 156 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24803 thread 157 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24804 thread 158 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24805 thread 159 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24806 thread 160 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24642 thread 161 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24807 thread 162 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24808 thread 163 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24809 thread 164 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24810 thread 165 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24811 thread 166 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24812 thread 167 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24813 thread 168 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24814 thread 169 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24815 thread 170 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24816 thread 171 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24817 thread 172 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24818 thread 173 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24819 thread 174 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24820 thread 175 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24821 thread 176 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24644 thread 177 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24822 thread 178 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24823 thread 179 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24824 thread 180 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24825 thread 181 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24826 thread 182 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24827 thread 183 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24829 thread 185 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24828 thread 184 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24830 thread 186 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24831 thread 187 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24832 thread 188 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24833 thread 189 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24834 thread 190 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24835 thread 191 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24836 thread 192 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24637 thread 193 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24837 thread 194 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24838 thread 195 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24839 thread 196 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24840 thread 197 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24841 thread 198 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24842 thread 199 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24843 thread 200 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24844 thread 201 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24845 thread 202 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24846 thread 203 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24847 thread 204 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24848 thread 205 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24849 thread 206 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24850 thread 207 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24851 thread 208 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24645 thread 209 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24852 thread 210 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24853 thread 211 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24854 thread 212 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24855 thread 213 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24856 thread 214 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24857 thread 215 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24858 thread 216 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24859 thread 217 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24860 thread 218 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24861 thread 219 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24862 thread 220 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24863 thread 221 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24864 thread 222 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24865 thread 223 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24866 thread 224 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24635 thread 225 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24867 thread 226 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24868 thread 227 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24869 thread 228 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24870 thread 229 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24871 thread 230 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24872 thread 231 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24873 thread 232 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24874 thread 233 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24875 thread 234 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24876 thread 235 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24877 thread 236 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24878 thread 237 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24879 thread 238 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24880 thread 239 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24881 thread 240 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24634 thread 241 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24882 thread 242 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24883 thread 243 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24884 thread 244 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24885 thread 245 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24886 thread 246 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24887 thread 247 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24888 thread 248 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24889 thread 249 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24890 thread 250 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24891 thread 251 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24892 thread 252 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24893 thread 253 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24894 thread 254 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24895 thread 255 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 24580 tid 24896 thread 256 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 4.03 s, testing time 0.01 s
# DEEPMD INFO    batch     200 training time 3.33 s, testing time 0.01 s
# DEEPMD INFO    batch     300 training time 40.68 s, testing time 0.01 s
# DEEPMD INFO    batch     400 training time 3.22 s, testing time 0.01 s
