# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine

# %%
from deepmd.calculator import DP
# Out:
# 2022-03-21 16:42:24.354362: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-21 16:42:24.354408: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
setting = {'basis':'6-31g', 'spin':0, 'xc':False, 'restricted':True, 'verbose':3}
geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./water.xyz',**setting)
geo.opt_algorithm = 'lbfgs'
geo.kernel()
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.02313993017 will be used
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 16618 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18523 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18524 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18525 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18526 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18527 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18530 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18528 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18529 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18532 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18533 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18531 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18534 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18535 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18536 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 16618 tid 18537 thread 15 bound to OS proc set 15
# converged SCF energy = -75.8174743597153
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-03-21 17:32:03.732147: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-21 17:32:03.732191: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# /home/jingheng/venv/lib/python3.9/site-packages/deepmd/utils/data_system.py:158: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (11 > 1)
#   warnings.warn("system %s required batch size is larger than the size of the dataset %s (%d > %d)" % \
# 2022-03-21 17:32:07.676726: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-21 17:32:07.679305: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-21 17:32:07.679339: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-21 17:32:07.679369: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Bai-Group): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-15
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 16 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 8 cores/socket x 2 threads/core (8 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 12 maps to socket 0 core 6 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 13 maps to socket 0 core 6 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 14 maps to socket 0 core 7 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 15 maps to socket 0 core 7 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18608 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18611 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18612 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18613 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18615 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18617 thread 7 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18616 thread 6 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18614 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18618 thread 8 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18619 thread 9 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18620 thread 10 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18621 thread 11 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18622 thread 12 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18623 thread 13 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18624 thread 14 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18625 thread 15 bound to OS proc set 15
# DEEPMD INFO    training data with min nbor dist: 1.0065080572951215
# DEEPMD INFO    training data with max nbor size: [1, 2]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/jingheng/deepmd-kit/_skbuild/linux-x86_64-3.9/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Bai-Group
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       3      11       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18609 thread 16 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18627 thread 18 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18626 thread 17 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18628 thread 19 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18629 thread 20 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18630 thread 21 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18631 thread 22 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18632 thread 23 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18634 thread 25 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18633 thread 24 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18635 thread 26 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18636 thread 27 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18637 thread 28 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18638 thread 29 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18639 thread 30 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18640 thread 31 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18539 thread 32 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 5000, decay_rate 0.598777, final lr will be 3.51e-08
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18607 thread 33 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18645 thread 35 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18644 thread 34 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18646 thread 36 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18647 thread 37 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18650 thread 40 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18648 thread 38 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18649 thread 39 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18651 thread 41 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18652 thread 42 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18653 thread 43 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18654 thread 44 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18656 thread 46 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18657 thread 47 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18655 thread 45 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18658 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18606 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18659 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18660 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18661 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18662 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18663 thread 54 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18664 thread 55 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18665 thread 56 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18666 thread 57 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18667 thread 58 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18668 thread 59 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18669 thread 60 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18670 thread 61 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18671 thread 62 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18672 thread 63 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18673 thread 64 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18598 thread 65 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18674 thread 66 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18675 thread 67 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18676 thread 68 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18677 thread 69 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18678 thread 70 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18679 thread 71 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18680 thread 72 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18681 thread 73 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18682 thread 74 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18683 thread 75 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18684 thread 76 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18685 thread 77 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18686 thread 78 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18687 thread 79 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18688 thread 80 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18594 thread 81 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18689 thread 82 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18690 thread 83 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18691 thread 84 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18692 thread 85 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18693 thread 86 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18694 thread 87 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18695 thread 88 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18696 thread 89 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18697 thread 90 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18698 thread 91 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18699 thread 92 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18700 thread 93 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18701 thread 94 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18702 thread 95 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18703 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18596 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18704 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18705 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18706 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18707 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18708 thread 102 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18709 thread 103 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18710 thread 104 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18711 thread 105 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18712 thread 106 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18713 thread 107 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18714 thread 108 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18715 thread 109 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18716 thread 110 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18717 thread 111 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18718 thread 112 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18603 thread 113 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18719 thread 114 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18720 thread 115 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18721 thread 116 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18722 thread 117 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18723 thread 118 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18724 thread 119 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18725 thread 120 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18726 thread 121 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18727 thread 122 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18728 thread 123 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18729 thread 124 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18730 thread 125 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18731 thread 126 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18732 thread 127 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18733 thread 128 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18601 thread 129 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18734 thread 130 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18735 thread 131 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18736 thread 132 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18737 thread 133 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18738 thread 134 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18739 thread 135 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18740 thread 136 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18741 thread 137 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18742 thread 138 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18743 thread 139 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18744 thread 140 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18745 thread 141 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18746 thread 142 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18747 thread 143 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18748 thread 144 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18604 thread 145 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18749 thread 146 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18750 thread 147 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18751 thread 148 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18752 thread 149 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18753 thread 150 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18754 thread 151 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18755 thread 152 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18756 thread 153 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18757 thread 154 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18758 thread 155 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18759 thread 156 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18760 thread 157 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18761 thread 158 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18762 thread 159 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18763 thread 160 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18605 thread 161 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18764 thread 162 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18765 thread 163 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18766 thread 164 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18767 thread 165 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18768 thread 166 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18769 thread 167 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18770 thread 168 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18771 thread 169 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18772 thread 170 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18773 thread 171 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18774 thread 172 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18775 thread 173 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18776 thread 174 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18777 thread 175 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18778 thread 176 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18600 thread 177 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18779 thread 178 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18780 thread 179 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18781 thread 180 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18782 thread 181 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18783 thread 182 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18784 thread 183 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18785 thread 184 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18786 thread 185 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18787 thread 186 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18788 thread 187 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18789 thread 188 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18790 thread 189 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18791 thread 190 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18792 thread 191 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18793 thread 192 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18602 thread 193 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18794 thread 194 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18795 thread 195 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18796 thread 196 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18797 thread 197 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18798 thread 198 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18799 thread 199 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18800 thread 200 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18801 thread 201 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18802 thread 202 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18803 thread 203 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18804 thread 204 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18805 thread 205 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18806 thread 206 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18807 thread 207 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18808 thread 208 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18595 thread 209 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18809 thread 210 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18810 thread 211 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18811 thread 212 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18812 thread 213 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18813 thread 214 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18814 thread 215 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18815 thread 216 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18816 thread 217 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18817 thread 218 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18818 thread 219 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18819 thread 220 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18820 thread 221 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18821 thread 222 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18822 thread 223 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18823 thread 224 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18599 thread 225 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18824 thread 226 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18825 thread 227 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18826 thread 228 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18827 thread 229 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18828 thread 230 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18829 thread 231 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18830 thread 232 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18831 thread 233 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18832 thread 234 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18833 thread 235 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18834 thread 236 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18835 thread 237 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18836 thread 238 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18837 thread 239 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18838 thread 240 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18597 thread 241 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18839 thread 242 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18840 thread 243 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18841 thread 244 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18842 thread 245 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18843 thread 246 bound to OS proc set 12
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18844 thread 247 bound to OS proc set 14
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18845 thread 248 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18846 thread 249 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18847 thread 250 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18848 thread 251 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18849 thread 252 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18850 thread 253 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18851 thread 254 bound to OS proc set 13
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18852 thread 255 bound to OS proc set 15
# OMP: Info #254: KMP_AFFINITY: pid 18539 tid 18853 thread 256 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 1.57 s, testing time 0.00 s
# DEEPMD INFO    batch     200 training time 0.98 s, testing time 0.00 s
# DEEPMD INFO    batch     300 training time 0.96 s, testing time 0.00 s
# DEEPMD INFO    batch     400 training time 0.98 s, testing time 0.00 s
# DEEPMD INFO    batch     500 training time 0.96 s, testing time 0.00 s
# DEEPMD INFO    batch     600 training time 0.96 s, testing time 0.00 s
# DEEPMD INFO    batch     700 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    batch     800 training time 0.94 s, testing time 0.00 s
# DEEPMD INFO    batch     900 training time 0.94 s, testing time 0.00 s
# DEEPMD INFO    batch    1000 training time 0.97 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 0.89 s, testing time 0.00 s
# DEEPMD INFO    batch    1200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    1300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    1700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    1800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    1900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2000 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    2200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    2300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    2700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    2900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    3200 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3300 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    3600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    3900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    4100 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    4200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    4300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    4500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    4900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5000 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    5100 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5200 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    5400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    5700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    5800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    5900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    6000 training time 0.84 s, testing time 0.00 s
# WARNING:tensorflow:From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD WARNING From /home/jingheng/venv/lib/python3.9/site-packages/tensorflow/python/training/saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    6100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch    6200 training time 0.94 s, testing time 0.00 s
# DEEPMD INFO    batch    6300 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    6400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    6500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    6600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    6900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    7100 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    7200 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch    7300 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch    7400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    7500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    7700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    7800 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch    7900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    8100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch    8200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    8300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    8400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8500 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    8600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    8900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9000 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    9100 training time 0.89 s, testing time 0.00 s
# DEEPMD INFO    batch    9200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch    9300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch    9400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch    9900 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   10000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   10100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   10200 training time 0.93 s, testing time 0.00 s
# DEEPMD INFO    batch   10300 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch   10400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   10500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   10600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   10700 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   10800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   10900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   11000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   11100 training time 0.89 s, testing time 0.00 s
# DEEPMD INFO    batch   11200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch   11300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   11400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   11500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   11600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   11700 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   11800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   11900 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   12000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   12100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   12200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch   12300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   12400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   12500 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   12600 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   12700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   12800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   12900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   13000 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   13100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   13200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch   13300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   13400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   13500 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   13600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   13700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   13800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   13900 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   14000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   14100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   14200 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch   14300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   14400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   14500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   14600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   14700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   14800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   14900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   15000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   15100 training time 0.89 s, testing time 0.00 s
# DEEPMD INFO    batch   15200 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch   15300 training time 0.87 s, testing time 0.00 s
# DEEPMD INFO    batch   15400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   15500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   15600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   15700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   15800 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   15900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   16000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   16100 training time 0.89 s, testing time 0.00 s
# DEEPMD INFO    batch   16200 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch   16300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   16400 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   16500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   16600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   16700 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   16800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   16900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   17000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   17100 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch   17200 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   17300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   17400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   17500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   17600 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   17700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   17800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   17900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   18000 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   18100 training time 0.91 s, testing time 0.00 s
# DEEPMD INFO    batch   18200 training time 0.92 s, testing time 0.00 s
# DEEPMD INFO    batch   18300 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   18400 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   18500 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   18600 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   18700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   18800 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   18900 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   19000 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   19100 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   19200 training time 0.90 s, testing time 0.00 s
# DEEPMD INFO    batch   19300 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   19400 training time 0.86 s, testing time 0.00 s
# DEEPMD INFO    batch   19500 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   19600 training time 0.84 s, testing time 0.00 s
# DEEPMD INFO    batch   19700 training time 0.85 s, testing time 0.00 s
# DEEPMD INFO    batch   19800 training time 0.86 s, testing time 0.00 s
# ...
# DEEPMD INFO    batch   75800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   75900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   76000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   76100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   76200 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   76300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   76400 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   76500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   76600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   76700 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   76800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   76900 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   77000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   77100 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   77200 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   77300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   77400 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch   77500 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   77600 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   77700 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   77800 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   77900 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch   78000 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   78100 training time 1.32 s, testing time 0.01 s
# DEEPMD INFO    batch   78200 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   78300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   78400 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   78500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   78600 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   78700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   78800 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   78900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   79000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   79100 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   79200 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   79300 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   79400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   79500 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   79600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   79700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   79800 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   79900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   80000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   80100 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   80200 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   80300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   80400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   80500 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   80600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   80700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   80800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   80900 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   81000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   81100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   81200 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   81300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   81400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   81500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   81600 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   81700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   81800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   81900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   82000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   82100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   82200 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   82300 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch   82400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   82500 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   82600 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   82700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   82800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   82900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   83000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   83100 training time 1.27 s, testing time 0.01 s
# DEEPMD INFO    batch   83200 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   83300 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   83400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   83500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   83600 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   83700 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   83800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   83900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   84000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   84100 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   84200 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   84300 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   84400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   84500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   84600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   84700 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   84800 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   84900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   85000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   85100 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   85200 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   85300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   85400 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   85500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   85600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   85700 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   85800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   85900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   86000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   86100 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   86200 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   86300 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   86400 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   86500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   86600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   86700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   86800 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   86900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   87000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   87100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   87200 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   87300 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   87400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   87500 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   87600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   87700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   87800 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   87900 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   88000 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   88100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   88200 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   88300 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   88400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   88500 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   88600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   88700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   88800 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   88900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   89000 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   89100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   89200 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   89300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   89400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   89500 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   89600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   89700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   89800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   89900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   90000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   90100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   90200 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   90300 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   90400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   90500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   90600 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   90700 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   90800 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   90900 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   91000 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   91100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   91200 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   91300 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   91400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   91500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   91600 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   91700 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   91800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   91900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   92000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   92100 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   92200 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   92300 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   92400 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   92500 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   92600 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   92700 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   92800 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   92900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   93000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   93100 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   93200 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   93300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   93400 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   93500 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   93600 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   93700 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   93800 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   93900 training time 1.19 s, testing time 0.01 s
# DEEPMD INFO    batch   94000 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   94100 training time 1.27 s, testing time 0.01 s
# DEEPMD INFO    batch   94200 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   94300 training time 1.20 s, testing time 0.01 s
# DEEPMD INFO    batch   94400 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   94500 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   94600 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   94700 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   94800 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch   94900 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   95000 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   95100 training time 1.31 s, testing time 0.01 s
# DEEPMD INFO    batch   95200 training time 1.28 s, testing time 0.01 s
# DEEPMD INFO    batch   95300 training time 1.21 s, testing time 0.01 s
# DEEPMD INFO    batch   95400 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   95500 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   95600 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch   95700 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   95800 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch   95900 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    batch   96000 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch   96100 training time 1.34 s, testing time 0.01 s
# DEEPMD INFO    batch   96200 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   96300 training time 1.24 s, testing time 0.01 s
# DEEPMD INFO    batch   96400 training time 1.27 s, testing time 0.01 s
# DEEPMD INFO    batch   96500 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   96600 training time 1.28 s, testing time 0.01 s
# DEEPMD INFO    batch   96700 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch   96800 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch   96900 training time 1.40 s, testing time 0.01 s

# %%
from pyscf import gto, scf

mol = gto.Mole(atom='''
O        3.37554198       1.98306445       1.77042260
O       26.17128840       1.15953296       1.70257011
H        3.48718928       1.81771738       1.72566221
H        3.36969874       1.99171817       1.77276519
H       26.20859573       1.24129313       1.88623203
H       26.16933587       1.15525391       1.69295785''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.max_cycle = 100
mf.kernel()
# Out:
# converged SCF energy = 610.156839488383
# 610.1568394883827

# %%
mol = gto.Mole(atom='''
O        3.85028343       4.33435074      -1.46283114
O       32.83434364       4.59371931      -0.64864949
H        3.22764867       0.72764750       3.29111982
H        3.15449789       0.73050176       3.44056131
H       22.91529053      -0.47107633       3.00121399
H       22.79958584      -0.56656299       2.92919549
''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
# Out:
# SCF not converged.
# SCF energy = -144.603063781376
# -144.603063781376

# %%
from pyscf import gto, scf

mol = gto.Mole(atom='''
O   3.63802      1.57110      1.76000
O  26.36198      1.57110      1.76000
H   3.95828      2.55412      1.74392
H   2.63613      1.66728      1.76493
H  26.09174      0.99418      2.56104
H  26.09550      0.99080      0.96072''',basis='6-31g').build()
mf = scf.RHF(mol)
mf.kernel()
print('111',mf.e_tot)
# Out:
# converged SCF energy = -151.950875830031
# 111 -151.9508758300306

# %%
from pyscf.data.nist import BOHR ,HARTREE2EV
print(0.00045 * HARTREE2EV/BOHR)
# Out:
# 0.023139930171428326
