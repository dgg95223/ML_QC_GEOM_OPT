# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine

# %%
from deepmd.calculator import DP
# Out:
# 2022-03-22 20:33:45.115102: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 20:33:45.115253: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
setting = {'basis':'6-31g', 'spin':0, 'xc':False, 'restricted':True, 'verbose':3}
geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./water.xyz',**setting)
geo.opt_algorithm = 'lbfgs'
geo.kernel()
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.10000000000 will be used
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4765 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4791 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4792 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4793 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4794 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4795 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4796 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4797 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4798 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4799 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4800 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 4801 thread 11 bound to OS proc set 11
# converged SCF energy = -75.8174743597152
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
# main.py 81 QC_coords0: [[6.87486144 2.96894871 3.32591798]
#  [7.48006512 4.82658729 3.29553118]
#  [4.98156373 3.15070257 3.33523433]]
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O     0.0072429678    -0.0393181577     0.0005179039
# 1 H     0.0047045727     0.0324210146    -0.0004933120
# 2 H    -0.0119506090     0.0068943152    -0.0000234460
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-03-22 20:33:50.676903: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 20:33:50.677060: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# 2022-03-22 20:33:56.533022: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 20:33:56.546667: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-22 20:33:56.546803: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4864 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4866 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4867 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4868 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4869 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4870 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4871 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4872 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4873 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4874 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4875 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4876 thread 11 bound to OS proc set 11
# /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data_system.py:159: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (11 > 1)
#   (self.system_dirs[ii], chk_ret[0], self.batch_size[ii], chk_ret[1]))
# DEEPMD INFO    training data with min nbor dist: 1.0065080572951215
# DEEPMD INFO    training data with max nbor size: [1, 2]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/dgg95223/deepmd-kit/_skbuild/linux-x86_64-3.7/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Deng-PC
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       3      11       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4863 thread 12 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4877 thread 13 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4878 thread 14 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4879 thread 15 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4880 thread 16 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4881 thread 17 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4882 thread 18 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4883 thread 19 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4884 thread 20 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4885 thread 21 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4886 thread 22 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4887 thread 23 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4803 thread 24 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 1000, decay_rate 0.358534, final lr will be 3.51e-08
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4860 thread 25 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4889 thread 26 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4890 thread 27 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4891 thread 28 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4892 thread 29 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4893 thread 30 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4894 thread 31 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4895 thread 32 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4896 thread 33 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4897 thread 34 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4898 thread 35 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4899 thread 36 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4853 thread 37 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4902 thread 38 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4903 thread 39 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4904 thread 40 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4905 thread 41 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4906 thread 42 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4907 thread 43 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4908 thread 44 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4909 thread 45 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4910 thread 46 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4911 thread 47 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4912 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4859 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4913 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4914 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4915 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4916 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4917 thread 54 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4918 thread 55 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4919 thread 56 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4920 thread 57 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4921 thread 58 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4922 thread 59 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4923 thread 60 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4854 thread 61 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4924 thread 62 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4925 thread 63 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4926 thread 64 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4927 thread 65 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4928 thread 66 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4929 thread 67 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4930 thread 68 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4931 thread 69 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4932 thread 70 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4933 thread 71 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4934 thread 72 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4858 thread 73 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4935 thread 74 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4936 thread 75 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4937 thread 76 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4938 thread 77 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4939 thread 78 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4940 thread 79 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4941 thread 80 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4942 thread 81 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4943 thread 82 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4944 thread 83 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4945 thread 84 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4861 thread 85 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4946 thread 86 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4947 thread 87 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4948 thread 88 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4949 thread 89 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4950 thread 90 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4951 thread 91 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4952 thread 92 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4953 thread 93 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4954 thread 94 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4955 thread 95 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4956 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4857 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4957 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4958 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4959 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4960 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4961 thread 102 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4962 thread 103 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4963 thread 104 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4964 thread 105 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4965 thread 106 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4966 thread 107 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4967 thread 108 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4855 thread 109 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4968 thread 110 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4969 thread 111 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4970 thread 112 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4971 thread 113 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4972 thread 114 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4973 thread 115 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4974 thread 116 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4975 thread 117 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4976 thread 118 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4977 thread 119 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4978 thread 120 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4856 thread 121 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4979 thread 122 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4980 thread 123 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4981 thread 124 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4982 thread 125 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4983 thread 126 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4984 thread 127 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4985 thread 128 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4986 thread 129 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4987 thread 130 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4988 thread 131 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4989 thread 132 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4862 thread 133 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4990 thread 134 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4991 thread 135 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4992 thread 136 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4993 thread 137 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4994 thread 138 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4995 thread 139 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4996 thread 140 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4997 thread 141 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4998 thread 142 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 4999 thread 143 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 4803 tid 5000 thread 144 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 2.45 s, testing time 0.00 s
# DEEPMD INFO    batch     200 training time 1.43 s, testing time 0.00 s
# DEEPMD INFO    batch     300 training time 1.40 s, testing time 0.01 s
# DEEPMD INFO    batch     400 training time 1.37 s, testing time 0.00 s
# DEEPMD INFO    batch     500 training time 1.44 s, testing time 0.00 s
# DEEPMD INFO    batch     600 training time 1.35 s, testing time 0.00 s
# DEEPMD INFO    batch     700 training time 1.44 s, testing time 0.01 s
# DEEPMD INFO    batch     800 training time 1.42 s, testing time 0.01 s
# DEEPMD INFO    batch     900 training time 1.35 s, testing time 0.00 s
# DEEPMD INFO    batch    1000 training time 1.35 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    1200 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    1300 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    1400 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    1500 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    1600 training time 1.25 s, testing time 0.01 s
# DEEPMD INFO    batch    1700 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    1800 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    1900 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    2000 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    2200 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch    2300 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    2400 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    2500 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    2600 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    2700 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    2800 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    2900 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    3000 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    3200 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    3300 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    3400 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    3500 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    3600 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    3700 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    3800 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    3900 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    4000 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    4100 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    4200 training time 1.19 s, testing time 0.00 s
# DEEPMD INFO    batch    4300 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    4400 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    4500 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    4600 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    4700 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    4800 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    4900 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    5000 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    5100 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    5200 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch    5300 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch    5400 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    5500 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    5600 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    5700 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    5800 training time 1.22 s, testing time 0.01 s
# DEEPMD INFO    batch    5900 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch    6000 training time 1.21 s, testing time 0.00 s
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1058: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1058: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    6100 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    6200 training time 1.31 s, testing time 0.00 s
# DEEPMD INFO    batch    6300 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    6400 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch    6500 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    6600 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    6700 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    6800 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    6900 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    7000 training time 1.23 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    7100 training time 1.31 s, testing time 0.01 s
# DEEPMD INFO    batch    7200 training time 1.30 s, testing time 0.00 s
# DEEPMD INFO    batch    7300 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    7400 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    7500 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    7600 training time 1.24 s, testing time 0.00 s
# DEEPMD INFO    batch    7700 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    7800 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    7900 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    8000 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    8100 training time 1.26 s, testing time 0.01 s
# DEEPMD INFO    batch    8200 training time 1.37 s, testing time 0.00 s
# DEEPMD INFO    batch    8300 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    8400 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    8500 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    8600 training time 1.22 s, testing time 0.00 s
# DEEPMD INFO    batch    8700 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    8800 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch    8900 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    9000 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    9100 training time 1.29 s, testing time 0.00 s
# DEEPMD INFO    batch    9200 training time 1.32 s, testing time 0.00 s
# DEEPMD INFO    batch    9300 training time 1.25 s, testing time 0.00 s
# DEEPMD INFO    batch    9400 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    batch    9500 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    9600 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    9700 training time 1.21 s, testing time 0.00 s
# DEEPMD INFO    batch    9800 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch    9900 training time 1.20 s, testing time 0.00 s
# DEEPMD INFO    batch   10000 training time 1.23 s, testing time 0.00 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    finished training
# DEEPMD INFO    wall time: 150.029 s
# 2022-03-22 20:36:30.988091: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 20:36:30.988257: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-22 20:36:33.978055: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-22 20:36:33.978225: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# 2022-03-22 20:36:33.978655: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    Restoring parameters from ./model.ckpt-10000
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    1150 ops in the final graph.
# 2022-03-22 20:36:36.408289: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 20:36:36.408457: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-03-22 20:36:38.717325: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-22 20:36:38.717458: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# 2022-03-22 20:36:38.717926: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 1: compress the model
# DEEPMD WARNING Switch to serial execution due to lack of horovod module.
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/dgg95223/deepmd-kit/_skbuild/linux-x86_64-3.7/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Deng-PC
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    training data with lower boundary: -0.12125570974870829
# DEEPMD INFO    training data with upper boundary: 10.127023945499651
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5156 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5219 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5220 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5221 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5222 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5223 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5224 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5225 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5226 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5227 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5228 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 5156 tid 5229 thread 11 bound to OS proc set 11
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    finished compressing
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 2: freeze the model
# INFO:tensorflow:Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    786 ops in the final graph.
# optimizer.py 77: [[3.63802 1.5711  1.76   ]
#  [3.95828 2.55412 1.74392]
#  [2.63613 1.66728 1.76493]]
# 2022-03-22 20:36:48.576373: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 20:36:48.593207: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-22 20:36:48.593351: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
#        Step     Time          Energy          fmax
# LBFGS:    0 20:36:49    -2063.098562   2.05597e+00
# LBFGS:    1 20:36:49    -2063.219417   2.54006e+00
# LBFGS:    2 20:36:49    -2063.333216   8.19802e+00
# LBFGS:    3 20:36:49    -2063.255235   2.41992e+00
# LBFGS:    4 20:36:49    -2063.394456   3.47081e+00
# LBFGS:    5 20:36:49    -2063.134634   2.28171e+00
# LBFGS:    6 20:36:49    -2063.067306   2.26384e+00
# LBFGS:    7 20:36:49    -2063.107750   4.93708e+00
# LBFGS:    8 20:36:49    -2062.977725   1.66169e+00
# LBFGS:    9 20:36:49    -2062.982327   1.05045e+00
# LBFGS:   10 20:36:49    -2062.983279   1.49234e+00
# LBFGS:   11 20:36:49    -2062.984367   1.19483e+00
# LBFGS:   12 20:36:49    -2062.983885   1.42922e+00
# LBFGS:   13 20:36:49    -2062.984278   1.36103e+00
# LBFGS:   14 20:36:49    -2062.983035   1.51664e+00
# LBFGS:   15 20:36:49    -2062.981822   1.60053e+00
# LBFGS:   16 20:36:49    -2062.976862   1.80140e+00
# LBFGS:   17 20:36:49    -2062.966947   2.00496e+00
# LBFGS:   18 20:36:49    -2062.944964   2.17377e+00
# LBFGS:   19 20:36:49    -2062.908151   2.09397e+00
# LBFGS:   20 20:36:49    -2062.861168   1.49211e+00
# LBFGS:   21 20:36:49    -2062.832622   4.85405e-01
# LBFGS:   22 20:36:49    -2062.829500   2.99841e-02
# LBFGS:   23 20:36:49    -2062.829405   1.69436e-02
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5235 thread 12 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5237 thread 13 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5238 thread 14 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5239 thread 15 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5240 thread 16 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5241 thread 17 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5242 thread 18 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5243 thread 19 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5244 thread 20 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5245 thread 21 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5246 thread 22 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 4765 tid 5247 thread 23 bound to OS proc set 11
# main.py 94: QC_coords1 [[6.65622104 3.30085322 3.32254553]
#  [7.66600561 4.62498906 3.29724514]
#  [5.01426364 3.02039631 3.33689282]]
# converged SCF energy = -75.7921684511749
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O    -0.0574448201     0.0955464012    -0.0010038344
# 1 H    -0.0505409444    -0.0958206573     0.0016892180
# 2 H     0.1079807525     0.0002731534    -0.0006836075
# ----------------------------------------------
# --------------- RKS gradients ---------------
#          x                y                z
# 0 O    -0.0574448201     0.0955464012    -0.0010038344
# 1 H    -0.0505409444    -0.0958206573     0.0016892180
# 2 H     0.1079807525     0.0002731534    -0.0006836075
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     2      ###
# 			###########################################
# 2022-03-22 20:36:51.308120: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 20:36:51.308296: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# 2022-03-22 20:36:56.910654: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 20:36:56.925479: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-22 20:36:56.925643: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# ...
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17609 thread 43 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17610 thread 44 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17611 thread 45 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17612 thread 46 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17613 thread 47 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17614 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17560 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17615 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17616 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17617 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17618 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17619 thread 54 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17620 thread 55 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17621 thread 56 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17622 thread 57 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17623 thread 58 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17624 thread 59 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17625 thread 60 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17567 thread 61 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17626 thread 62 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17627 thread 63 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17628 thread 64 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17629 thread 65 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17630 thread 66 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17631 thread 67 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17632 thread 68 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17633 thread 69 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17634 thread 70 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17635 thread 71 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17636 thread 72 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17561 thread 73 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17637 thread 74 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17638 thread 75 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17639 thread 76 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17640 thread 77 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17641 thread 78 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17642 thread 79 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17643 thread 80 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17644 thread 81 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17645 thread 82 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17646 thread 83 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17647 thread 84 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17559 thread 85 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17648 thread 86 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17649 thread 87 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17650 thread 88 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17651 thread 89 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17652 thread 90 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17653 thread 91 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17654 thread 92 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17655 thread 93 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17656 thread 94 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17657 thread 95 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17658 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17563 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17659 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17660 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17661 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17662 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17663 thread 102 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17664 thread 103 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17665 thread 104 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17666 thread 105 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17667 thread 106 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17668 thread 107 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17669 thread 108 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17565 thread 109 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17670 thread 110 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17671 thread 111 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17672 thread 112 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17673 thread 113 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17674 thread 114 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17675 thread 115 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17676 thread 116 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17677 thread 117 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17678 thread 118 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17679 thread 119 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17680 thread 120 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17562 thread 121 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17681 thread 122 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17682 thread 123 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17683 thread 124 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17684 thread 125 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17685 thread 126 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17686 thread 127 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17687 thread 128 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17688 thread 129 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17689 thread 130 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17690 thread 131 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17691 thread 132 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17558 thread 133 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17692 thread 134 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17693 thread 135 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17694 thread 136 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17695 thread 137 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17696 thread 138 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17697 thread 139 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17698 thread 140 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17699 thread 141 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17700 thread 142 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17701 thread 143 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 17508 tid 17702 thread 144 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 5.70 s, testing time 0.02 s
# DEEPMD INFO    batch     200 training time 4.64 s, testing time 0.02 s
# DEEPMD INFO    batch     300 training time 4.85 s, testing time 0.02 s
# DEEPMD INFO    batch     400 training time 4.64 s, testing time 0.02 s
# DEEPMD INFO    batch     500 training time 4.61 s, testing time 0.02 s
# DEEPMD INFO    batch     600 training time 4.61 s, testing time 0.02 s
# DEEPMD INFO    batch     700 training time 4.75 s, testing time 0.02 s
# DEEPMD INFO    batch     800 training time 4.50 s, testing time 0.02 s
# DEEPMD INFO    batch     900 training time 4.55 s, testing time 0.02 s
# DEEPMD INFO    batch    1000 training time 4.60 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 3.87 s, testing time 0.02 s
# DEEPMD INFO    batch    1200 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    1300 training time 3.75 s, testing time 0.02 s
# DEEPMD INFO    batch    1400 training time 3.76 s, testing time 0.02 s
# DEEPMD INFO    batch    1500 training time 3.75 s, testing time 0.02 s
# DEEPMD INFO    batch    1600 training time 3.76 s, testing time 0.02 s
# DEEPMD INFO    batch    1700 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    1800 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    1900 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    2000 training time 3.78 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    2200 training time 3.79 s, testing time 0.02 s
# DEEPMD INFO    batch    2300 training time 3.75 s, testing time 0.02 s
# DEEPMD INFO    batch    2400 training time 3.78 s, testing time 0.02 s
# DEEPMD INFO    batch    2500 training time 3.82 s, testing time 0.02 s
# DEEPMD INFO    batch    2600 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    2700 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    2800 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    2900 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    3000 training time 3.79 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    3200 training time 4.01 s, testing time 0.02 s
# DEEPMD INFO    batch    3300 training time 3.77 s, testing time 0.02 s
# DEEPMD INFO    batch    3400 training time 3.98 s, testing time 0.02 s
# DEEPMD INFO    batch    3500 training time 3.88 s, testing time 0.02 s
# DEEPMD INFO    batch    3600 training time 3.83 s, testing time 0.02 s
# DEEPMD INFO    batch    3700 training time 3.94 s, testing time 0.02 s
# DEEPMD INFO    batch    3800 training time 3.80 s, testing time 0.02 s
# Traceback (most recent call last):
#   File "/home/dgg95223/venv/bin/dp", line 8, in <module>
#     sys.exit(main())
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/main.py", line 473, in main
#     train_dp(**dict_args)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/train.py", line 106, in train
#     _do_work(jdata, run_opt, is_compress)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/train.py", line 167, in _do_work
#     model.train(train_data, valid_data)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/train/trainer.py", line 514, in train
#     options=prf_options, run_metadata=prf_run_metadata)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/sess.py", line 21, in run_sess
#     return sess.run(*args, **kwargs)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 971, in run
#     run_metadata_ptr)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1194, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1374, in _do_run
#     run_metadata)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1380, in _do_call
#     return fn(*args)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1364, in _run_fn
#     target_list, run_metadata)
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1458, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4765/1252094722.py in <module>
#       2 geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./water.xyz',**setting)
#       3 geo.opt_algorithm = 'lbfgs'
# ----> 4 geo.kernel()
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/main.py in kernel(self)
#      96 			'''%iter)
#      97                         ML = ML_engine.MLEngine(work_path=self.work_path, ml_engine=self.ml_engine).build()
# ---> 98                         ML.run()
#      99
#     100 			Opt = optimizer.Optimizer(xyz_path=self.xyz_path,
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/ML_engine.py in run(self)
#      34     def run(self):
#      35
# ---> 36         self.training()
#      37         self.freeze()
#      38         self.compress()
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/ML_engine.py in training(self)
#      21
#      22     def training(self):
# ---> 23         train = subprocess.run('dp train %s'%self.input_path, shell=True)
#      24         assert train.returncode == 0, 'An error occurred during training process.'
#      25
#
# ~/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
# --> 490             stdout, stderr = process.communicate(input, timeout=timeout)
#     491         except TimeoutExpired as exc:
#     492             process.kill()
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     954                 stderr = self.stderr.read()
#     955                 self.stderr.close()
# --> 956             self.wait()
#     957         else:
#     958             if timeout is not None:
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#    1017             endtime = _time() + timeout
#    1018         try:
# -> 1019             return self._wait(timeout=timeout)
#    1020         except KeyboardInterrupt:
#    1021             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1651                         if self.returncode is not None:
#    1652                             break  # Another thread waited.
# -> 1653                         (pid, sts) = self._try_wait(0)
#    1654                         # Check the pid and loop as waitpid has been known to
#    1655                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1609             """All callers to this function MUST hold self._waitpid_lock."""
#    1610             try:
# -> 1611                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1612             except ChildProcessError:
#    1613                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
