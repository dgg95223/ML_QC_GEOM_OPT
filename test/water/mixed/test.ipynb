# %%
from MQGO import data, main, ML_engine, optimizer, QC_engine 
from deepmd.calculator import DP
import subprocess
import numpy as np
import json
# Out:
# 2022-05-01 20:18:16.698318: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-01 20:18:16.698676: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:root:Environment variable KMP_BLOCKTIME is empty. Use the default value 0
# WARNING:root:Environment variable KMP_AFFINITY is empty. Use the default value granularity=fine,verbose,compact,1,0

# %%
7d_steps = [3500]
tot_steps = [4000]
subprocess.run('cp water0.xyz water.xyz', shell=True)

index = 0
for ii in range(0,len(d_steps)):
    for jj in range(0,len(tot_steps)):
        js_setting = {}
        with open('./input0.json', 'r') as file:
            json_setting = json.load(file)
            print('after remake json: ',json_setting['learning_rate']['decay_steps'])
            
        json_setting['learning_rate']['decay_steps'] = d_steps[ii]
        json_setting['training']['numb_steps'] = tot_steps[jj]
        print('ii,jj:',ii,jj)
        print('before make json: ',json_setting['learning_rate']['decay_steps'])
        with open('./input.json', 'w') as js:
            json.dump(json_setting, js, indent=4)
        
        setting = {'basis':'6-31g', 'spin':0, 'xc':None, 'restricted':True, 'verbose':3, 'max_cycle':500}
        geo = main.MLgeomopt(qc_engine='pyscf', ml_engine='deepmd', work_path='./', xyz_path='./water.xyz',**setting)
        geo.opt_algorithm = 'lbfgs'
        geo.debug = True
        geo.have_init_qc_data = False
        geo.kernel()
        
        Opt = optimizer.Optimizer(xyz_path="water0.xyz",
									work_path="./",
									ml_engine='deepmd',
									outter_cycle=1,
									algorithm='lbfgs',
									max_opt_cycle=100)
        atom0 = Opt.ase_read_xyz()
        atom0.calc = DP(model='graph.pb')
        print(atom0.get_potential_energy())
        force0_ml = atom0.get_forces()

        forces = np.loadtxt('raw/force.raw')
        force0_qc = forces[0].reshape((6,3))

        delta = force0_qc-force0_ml
        with open('debug_diff_force.txt', 'a') as file:
            file.write('%24.18f\n'%atom0.get_potential_energy())
            for i in range(0, len(force0_qc)):
                for j in range(0, 3):
                    file.write('%24.18f'%delta[i][j])
                file.write('\n')
            file.write('\n')
            
        print('after dp: ',json_setting['learning_rate']['decay_steps'])
        subprocess.run('cp water0.xyz water.xyz', shell=True)
        # subprocess.run('rm input.json', shell=True)
# Out:
# WARNING:MQGO.main:No convergence tolarence is specified, default tolarence 0.10000000000 will be used
# after remake json:  4000
# ii,jj: 0 0
# before make json:  3500
# converged SCF energy = -151.950875830031
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0337296910    -0.0786105069     0.0009124778
# 1 O     0.0362318987     0.0781338011    -0.0003340143
# 2 H     0.0107666884     0.0643363502    -0.0009882872
# 3 H    -0.0444975432     0.0142743303     0.0000758114
# 4 H    -0.0182443977    -0.0390612787     0.0397229089
# 5 H    -0.0179863371    -0.0390726960    -0.0393888966
# ----------------------------------------------
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0337296910    -0.0786105069     0.0009124778
# 1 O     0.0362318987     0.0781338011    -0.0003340143
# 2 H     0.0107666884     0.0643363502    -0.0009882872
# 3 H    -0.0444975432     0.0142743303     0.0000758114
# 4 H    -0.0182443977    -0.0390612787     0.0397229089
# 5 H    -0.0179863371    -0.0390726960    -0.0393888966
# ----------------------------------------------
# converged SCF energy = -151.950878236942
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0337292118    -0.0786099790     0.0009124859
# 1 O     0.0362307172     0.0781334659    -0.0003340081
# 2 H     0.0107669962     0.0643361164    -0.0009882935
# 3 H    -0.0444976000     0.0142740728     0.0000758099
# 4 H    -0.0182436935    -0.0390611321     0.0397232184
# 5 H    -0.0179856316    -0.0390725440    -0.0393892126
# ----------------------------------------------
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0337292118    -0.0786099790     0.0009124859
# 1 O     0.0362307172     0.0781334659    -0.0003340081
# 2 H     0.0107669962     0.0643361164    -0.0009882935
# 3 H    -0.0444976000     0.0142740728     0.0000758099
# 4 H    -0.0182436935    -0.0390611321     0.0397232184
# 5 H    -0.0179856316    -0.0390725440    -0.0393892126
# ----------------------------------------------
# converged SCF energy = -151.950881128305
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0337286413    -0.0786093463     0.0009124957
# 1 O     0.0362293021     0.0781330579    -0.0003340006
# 2 H     0.0107673518     0.0643358345    -0.0009883012
# 3 H    -0.0444976723     0.0142737688     0.0000758082
# 4 H    -0.0182428431    -0.0390609548     0.0397235943
# 5 H    -0.0179847798    -0.0390723602    -0.0393895963
# ----------------------------------------------
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0337286413    -0.0786093463     0.0009124957
# 1 O     0.0362293021     0.0781330579    -0.0003340006
# 2 H     0.0107673518     0.0643358345    -0.0009883012
# 3 H    -0.0444976723     0.0142737688     0.0000758082
# 4 H    -0.0182428431    -0.0390609548     0.0397235943
# 5 H    -0.0179847798    -0.0390723602    -0.0393895963
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     1      ###
# 			###########################################
# 2022-05-02 23:18:39.737165: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-02 23:18:39.737303: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# 2022-05-02 23:18:44.942747: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-02 23:18:44.956482: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-02 23:18:44.956603: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15133 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15135 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15136 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15137 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15138 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15139 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15140 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15142 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15141 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15143 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15144 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15145 thread 11 bound to OS proc set 11
# /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data_system.py:159: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (6 > 1)
#   (self.system_dirs[ii], chk_ret[0], self.batch_size[ii], chk_ret[1]))
# DEEPMD INFO    training data with min nbor dist: 1.0065080572951215
# DEEPMD INFO    training data with max nbor size: [1, 2]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/dgg95223/deepmd-kit/_skbuild/linux-x86_64-3.7/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Deng-PC
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# DEEPMD INFO                                        ./raw/       6       6       1  1.000    F
# DEEPMD INFO    --------------------------------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    data stating... (this step may take long time)
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15132 thread 12 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15146 thread 13 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15147 thread 14 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15148 thread 15 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15149 thread 16 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15150 thread 17 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15151 thread 18 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15152 thread 19 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15153 thread 20 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15154 thread 21 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15155 thread 22 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15156 thread 23 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15072 thread 24 bound to OS proc set 0
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 3500, decay_rate 0.000127, final lr will be 1.27e-07
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15126 thread 25 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15157 thread 26 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15158 thread 27 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15159 thread 28 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15160 thread 29 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15161 thread 30 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15162 thread 31 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15163 thread 32 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15164 thread 33 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15165 thread 34 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15166 thread 35 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15167 thread 36 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15129 thread 37 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15168 thread 38 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15169 thread 39 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15170 thread 40 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15171 thread 41 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15172 thread 42 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15173 thread 43 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15174 thread 44 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15175 thread 45 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15176 thread 46 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15177 thread 47 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15178 thread 48 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15122 thread 49 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15179 thread 50 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15180 thread 51 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15181 thread 52 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15182 thread 53 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15183 thread 54 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15184 thread 55 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15185 thread 56 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15186 thread 57 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15187 thread 58 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15188 thread 59 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15189 thread 60 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15127 thread 61 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15190 thread 62 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15191 thread 63 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15192 thread 64 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15193 thread 65 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15194 thread 66 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15195 thread 67 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15196 thread 68 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15197 thread 69 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15198 thread 70 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15199 thread 71 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15200 thread 72 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15131 thread 73 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15201 thread 74 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15202 thread 75 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15203 thread 76 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15204 thread 77 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15205 thread 78 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15206 thread 79 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15207 thread 80 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15208 thread 81 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15209 thread 82 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15210 thread 83 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15211 thread 84 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15125 thread 85 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15212 thread 86 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15213 thread 87 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15214 thread 88 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15215 thread 89 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15216 thread 90 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15217 thread 91 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15218 thread 92 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15219 thread 93 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15220 thread 94 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15221 thread 95 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15222 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15128 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15223 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15224 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15225 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15226 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15227 thread 102 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15228 thread 103 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15229 thread 104 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15230 thread 105 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15231 thread 106 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15232 thread 107 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15233 thread 108 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15124 thread 109 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15234 thread 110 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15235 thread 111 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15236 thread 112 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15237 thread 113 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15238 thread 114 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15239 thread 115 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15240 thread 116 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15241 thread 117 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15242 thread 118 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15243 thread 119 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15244 thread 120 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15123 thread 121 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15245 thread 122 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15246 thread 123 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15247 thread 124 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15248 thread 125 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15249 thread 126 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15250 thread 127 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15251 thread 128 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15252 thread 129 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15253 thread 130 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15254 thread 131 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15255 thread 132 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15130 thread 133 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15256 thread 134 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15257 thread 135 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15258 thread 136 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15259 thread 137 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15260 thread 138 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15261 thread 139 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15262 thread 140 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15263 thread 141 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15264 thread 142 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15265 thread 143 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15072 tid 15266 thread 144 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 2.66 s, testing time 0.01 s
# DEEPMD INFO    batch     200 training time 1.72 s, testing time 0.01 s
# DEEPMD INFO    batch     300 training time 1.65 s, testing time 0.01 s
# DEEPMD INFO    batch     400 training time 1.60 s, testing time 0.01 s
# DEEPMD INFO    batch     500 training time 1.69 s, testing time 0.01 s
# DEEPMD INFO    batch     600 training time 1.65 s, testing time 0.01 s
# DEEPMD INFO    batch     700 training time 1.67 s, testing time 0.01 s
# DEEPMD INFO    batch     800 training time 1.69 s, testing time 0.01 s
# DEEPMD INFO    batch     900 training time 1.64 s, testing time 0.01 s
# DEEPMD INFO    batch    1000 training time 1.69 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 1.49 s, testing time 0.01 s
# DEEPMD INFO    batch    1200 training time 1.46 s, testing time 0.01 s
# DEEPMD INFO    batch    1300 training time 1.42 s, testing time 0.01 s
# DEEPMD INFO    batch    1400 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    1500 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    1600 training time 1.34 s, testing time 0.01 s
# DEEPMD INFO    batch    1700 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    1800 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    1900 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    2000 training time 1.39 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 1.42 s, testing time 0.01 s
# DEEPMD INFO    batch    2200 training time 1.41 s, testing time 0.01 s
# DEEPMD INFO    batch    2300 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    2400 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    2500 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    2600 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    2700 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    2800 training time 1.34 s, testing time 0.01 s
# DEEPMD INFO    batch    2900 training time 1.37 s, testing time 0.01 s
# DEEPMD INFO    batch    3000 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 1.45 s, testing time 0.01 s
# DEEPMD INFO    batch    3200 training time 1.45 s, testing time 0.01 s
# DEEPMD INFO    batch    3300 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    3400 training time 1.36 s, testing time 0.01 s
# DEEPMD INFO    batch    3500 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    3600 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    3700 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    3800 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    batch    3900 training time 1.38 s, testing time 0.01 s
# DEEPMD INFO    batch    4000 training time 1.35 s, testing time 0.01 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    finished training
# DEEPMD INFO    wall time: 68.949 s
# 2022-05-02 23:19:58.165876: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-02 23:19:58.166024: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-05-02 23:20:01.045920: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-02 23:20:01.046047: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# 2022-05-02 23:20:01.046447: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./model.ckpt-4000
# DEEPMD INFO    Restoring parameters from ./model.ckpt-4000
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    1150 ops in the final graph.
# 2022-05-02 23:20:03.284951: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-02 23:20:03.285089: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# 2022-05-02 23:20:05.343102: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-02 23:20:05.343225: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# 2022-05-02 23:20:05.343619: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 1: compress the model
# DEEPMD WARNING Switch to serial execution due to lack of horovod module.
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/dgg95223/deepmd-kit/_skbuild/linux-x86_64-3.7/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Deng-PC
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    training without frame parameter
# DEEPMD INFO    training data with lower boundary: -0.12126157751409793
# DEEPMD INFO    training data with upper boundary: 10.14822579752556
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15334 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15396 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15397 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15398 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15399 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15400 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15401 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15402 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15403 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15404 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15405 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15334 tid 15406 thread 11 bound to OS proc set 11
# DEEPMD INFO    built lr
# DEEPMD INFO    built network
# DEEPMD INFO    built training
# DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# DEEPMD INFO    initialize model from scratch
# DEEPMD INFO    finished compressing
# DEEPMD INFO
#
#
# DEEPMD INFO    stage 2: freeze the model
# INFO:tensorflow:Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    Restoring parameters from model-compression/model.ckpt
# DEEPMD INFO    The following nodes will be frozen: ['model_type', 'descrpt_attr/rcut', 'descrpt_attr/ntypes', 'model_attr/tmap', 'model_attr/model_type', 'model_attr/model_version', 'train_attr/min_nbor_dist', 'train_attr/training_script', 'o_energy', 'o_force', 'o_virial', 'o_atom_energy', 'o_atom_virial', 'fitting_attr/dfparam', 'fitting_attr/daparam']
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/entrypoints/freeze.py:244: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD WARNING From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/framework/convert_to_constants.py:929: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# DEEPMD INFO    786 ops in the final graph.
# optimizer.py 77: [[ 3.63802  1.5711   1.76   ]
#  [26.36198  1.5711   1.76   ]
#  [ 3.95828  2.55412  1.74392]
#  [ 2.63613  1.66728  1.76493]
#  [26.09174  0.99418  2.56104]
#  [26.0955   0.9908   0.96072]]
#        Step     Time          Energy          fmax
# LBFGS:    0 23:20:15    -4134.639526   4.45231e+00
# LBFGS:    1 23:20:15    -4135.869768   5.31866e+00
# LBFGS:    2 23:20:15    -4133.814415   6.39073e+00
# LBFGS:    3 23:20:15    -4134.336553   6.60584e+00
# LBFGS:    4 23:20:15    -4133.941655   7.71394e+00
# LBFGS:    5 23:20:15    -4134.214447   1.07998e+01
# LBFGS:    6 23:20:15    -4133.919353   3.18320e+00
# LBFGS:    7 23:20:15    -4133.998087   4.02993e+00
# LBFGS:    8 23:20:15    -4133.880606   3.19654e+00
# LBFGS:    9 23:20:15    -4133.856190   3.74598e+00
# LBFGS:   10 23:20:15    -4134.057344   5.50295e+00
# LBFGS:   11 23:20:15    -4133.791995   6.06592e+00
# LBFGS:   12 23:20:15    -4134.101747   6.20899e+00
# LBFGS:   13 23:20:15    -4133.610565   6.13229e+00
# LBFGS:   14 23:20:15    -4133.474268   6.65811e+00
# LBFGS:   15 23:20:15    -4133.023519   1.02341e+01
# LBFGS:   16 23:20:15    -4132.904809   8.70807e+00
# LBFGS:   17 23:20:15    -4132.794683   4.88649e+00
# LBFGS:   18 23:20:15    -4132.794215   6.11200e+00
# LBFGS:   19 23:20:15    -4132.805088   5.09321e+00
# LBFGS:   20 23:20:15    -4132.795005   6.07145e+00
# LBFGS:   21 23:20:15    -4132.795767   6.03317e+00
# LBFGS:   22 23:20:15    -4132.765425   7.06285e+00
# LBFGS:   23 23:20:15    -4132.722840   7.87115e+00
# LBFGS:   24 23:20:15    -4132.647837   8.12447e+00
# LBFGS:   25 23:20:15    -4132.497863   6.16584e+00
# LBFGS:   26 23:20:15    -4132.489825   5.56005e+00
# LBFGS:   27 23:20:15    -4132.341710   1.60018e+00
# LBFGS:   28 23:20:15    -4132.330473   8.78047e-01
# LBFGS:   29 23:20:15    -4132.319740   5.01237e-01
# LBFGS:   30 23:20:15    -4132.311231   5.00503e-01
# LBFGS:   31 23:20:15    -4132.308904   6.60771e-01
# LBFGS:   32 23:20:15    -4132.306594   5.97560e-01
# LBFGS:   33 23:20:15    -4132.303774   4.25529e-01
# LBFGS:   34 23:20:15    -4132.302178   2.95116e-01
# LBFGS:   35 23:20:15    -4132.302312   4.39856e-01
# LBFGS:   36 23:20:15    -4132.301277   2.58928e-01
# LBFGS:   37 23:20:15    -4132.301097   2.53642e-01
# LBFGS:   38 23:20:15    -4132.300987   2.48444e-01
# LBFGS:   39 23:20:15    -4132.300943   2.41511e-01
# LBFGS:   40 23:20:15    -4132.300936   2.37833e-01
# LBFGS:   41 23:20:15    -4132.300946   2.40066e-01
# LBFGS:   42 23:20:15    -4132.300666   2.00918e-01
# LBFGS:   43 23:20:15    -4132.300321   1.75947e-01
# LBFGS:   44 23:20:15    -4132.299457   1.33034e-01
# LBFGS:   45 23:20:15    -4132.298356   1.43332e-01
# LBFGS:   46 23:20:15    -4132.297651   8.92227e-02
# LBFGS:   47 23:20:15    -4132.298057   2.31577e-01
# LBFGS:   48 23:20:15    -4132.297501   5.60180e-02
# LBFGS:   49 23:20:15    -4132.297473   1.12251e-02
# LBFGS:   50 23:20:15    -4132.297470   2.41318e-03
# LBFGS:   51 23:20:15    -4132.297470   2.91035e-04
# converged SCF energy = -151.845847991863
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0000077011    -0.0000112890     0.0000002369
# 1 O     0.0000017292    -0.0000033643    -0.0000068822
# 2 H    -0.1428658461     0.0452262248     0.0002520901
# 3 H     0.1428581214    -0.0452149386    -0.0002523288
# 4 H    -0.0043801996    -0.0105132315    -0.1494106144
# 5 H     0.0043784939     0.0105165985     0.1494174984
# ----------------------------------------------
# --------------- RHF gradients ---------------
#          x                y                z
# 0 O     0.0000077011    -0.0000112890     0.0000002369
# 1 O     0.0000017292    -0.0000033643    -0.0000068822
# 2 H    -0.1428658461     0.0452262248     0.0002520901
# 3 H     0.1428581214    -0.0452149386    -0.0002523288
# 4 H    -0.0043801996    -0.0105132315    -0.1494106144
# 5 H     0.0043784939     0.0105165985     0.1494174984
# ----------------------------------------------
#
# 			###########################################
# 			###      Optimization cycle:     2      ###
# 			###########################################
# 2022-05-02 23:20:17.235113: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-02 23:20:17.235246: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:root:To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, TF_INTRA_OP_PARALLELISM_THREADS, and TF_INTER_OP_PARALLELISM_THREADS.
# WARNING:deepmd.train.run_options:Switch to serial execution due to lack of horovod module.
# DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# 2022-05-02 23:20:22.431563: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-02 23:20:22.446783: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-02 23:20:22.446960: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Deng-PC): /proc/driver/nvidia/version does not exist
# OMP: Info #155: KMP_AFFINITY: Initial OS proc set respected: 0-11
# OMP: Info #216: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #216: KMP_AFFINITY: x2APIC ids not unique.
# OMP: Info #216: KMP_AFFINITY: decoding legacy APIC ids.
# OMP: Info #216: KMP_AFFINITY: legacy APIC ids not unique.
# OMP: Info #220: KMP_AFFINITY: parsing /proc/cpuinfo.
# OMP: Info #157: KMP_AFFINITY: 12 available OS procs
# OMP: Info #158: KMP_AFFINITY: Uniform topology
# OMP: Info #287: KMP_AFFINITY: topology layer "LL cache" is equivalent to "socket".
# OMP: Info #192: KMP_AFFINITY: 1 socket x 6 cores/socket x 2 threads/core (6 total cores)
# OMP: Info #218: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #172: KMP_AFFINITY: OS proc 0 maps to socket 0 core 0 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 1 maps to socket 0 core 0 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 2 maps to socket 0 core 1 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 3 maps to socket 0 core 1 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 4 maps to socket 0 core 2 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 5 maps to socket 0 core 2 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 6 maps to socket 0 core 3 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 7 maps to socket 0 core 3 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 8 maps to socket 0 core 4 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 9 maps to socket 0 core 4 thread 1
# OMP: Info #172: KMP_AFFINITY: OS proc 10 maps to socket 0 core 5 thread 0
# OMP: Info #172: KMP_AFFINITY: OS proc 11 maps to socket 0 core 5 thread 1
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15475 thread 0 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15477 thread 1 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15478 thread 2 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15479 thread 3 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15480 thread 4 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15481 thread 5 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15482 thread 6 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15483 thread 7 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15484 thread 8 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15485 thread 9 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15486 thread 10 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15487 thread 11 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15474 thread 12 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15488 thread 13 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15489 thread 14 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15490 thread 15 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15491 thread 16 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15492 thread 17 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15493 thread 18 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15494 thread 19 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15495 thread 20 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15496 thread 21 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15498 thread 23 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 15414 tid 15497 thread 22 bound to OS proc set 9
# /home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data_system.py:159: UserWarning: system ./raw/ required batch size is larger than the size of the dataset raw/set.000 (6 > 2)
#   (self.system_dirs[ii], chk_ret[0], self.batch_size[ii], chk_ret[1]))
# DEEPMD INFO    training data with min nbor dist: 0.8397817195661273
# DEEPMD INFO    training data with max nbor size: [1, 2]
# DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# DEEPMD INFO    Please read and cite:
# DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# DEEPMD INFO    installed to:         /home/dgg95223/deepmd-kit/_skbuild/linux-x86_64-3.7/cmake-install
# DEEPMD INFO    source :              v2.1.0
# DEEPMD INFO    source brach:         master
# DEEPMD INFO    source commit:        3e54fea
# DEEPMD INFO    source commit at:     2022-03-07 11:41:41 +0800
# DEEPMD INFO    build float prec:     double
# DEEPMD INFO    build with tf inc:    /home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/include
# DEEPMD INFO    build with tf lib:
# DEEPMD INFO    ---Summary of the training---------------------------------------
# DEEPMD INFO    running on:           Deng-PC
# DEEPMD INFO    computing device:     cpu:0
# DEEPMD INFO    CUDA_VISIBLE_DEVICES: unset
# DEEPMD INFO    Count of visible GPU: 0
# DEEPMD INFO    num_intra_threads:    0
# DEEPMD INFO    num_inter_threads:    0
# DEEPMD INFO    -----------------------------------------------------------------
# DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# DEEPMD INFO    found 1 system(s):
# DEEPMD INFO                                        system  natoms  bch_sz   n_bch   prob  pbc
# ...
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1483 thread 63 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1484 thread 64 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1485 thread 65 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1486 thread 66 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1487 thread 67 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1488 thread 68 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1489 thread 69 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1490 thread 70 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1491 thread 71 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1492 thread 72 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1413 thread 73 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1493 thread 74 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1494 thread 75 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1495 thread 76 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1496 thread 77 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1497 thread 78 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1498 thread 79 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1499 thread 80 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1500 thread 81 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1501 thread 82 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1502 thread 83 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1503 thread 84 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1411 thread 85 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1504 thread 86 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1505 thread 87 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1506 thread 88 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1507 thread 89 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1508 thread 90 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1509 thread 91 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1510 thread 92 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1511 thread 93 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1512 thread 94 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1513 thread 95 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1514 thread 96 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1414 thread 97 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1515 thread 98 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1516 thread 99 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1517 thread 100 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1518 thread 101 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1519 thread 102 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1520 thread 103 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1521 thread 104 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1522 thread 105 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1523 thread 106 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1524 thread 107 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1525 thread 108 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1420 thread 109 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1531 thread 110 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1532 thread 111 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1533 thread 112 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1534 thread 113 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1535 thread 114 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1536 thread 115 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1537 thread 116 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1538 thread 117 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1539 thread 118 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1540 thread 119 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1541 thread 120 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1415 thread 121 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1543 thread 122 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1544 thread 123 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1545 thread 124 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1546 thread 125 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1547 thread 126 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1548 thread 127 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1549 thread 128 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1550 thread 129 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1551 thread 130 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1552 thread 131 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1553 thread 132 bound to OS proc set 0
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1416 thread 133 bound to OS proc set 2
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1554 thread 134 bound to OS proc set 4
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1555 thread 135 bound to OS proc set 6
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1556 thread 136 bound to OS proc set 8
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1557 thread 137 bound to OS proc set 10
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1558 thread 138 bound to OS proc set 1
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1559 thread 139 bound to OS proc set 3
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1560 thread 140 bound to OS proc set 5
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1561 thread 141 bound to OS proc set 7
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1562 thread 142 bound to OS proc set 9
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1563 thread 143 bound to OS proc set 11
# OMP: Info #254: KMP_AFFINITY: pid 1355 tid 1564 thread 144 bound to OS proc set 0
# DEEPMD INFO    batch     100 training time 5.92 s, testing time 0.02 s
# DEEPMD INFO    batch     200 training time 4.91 s, testing time 0.02 s
# DEEPMD INFO    batch     300 training time 4.90 s, testing time 0.02 s
# DEEPMD INFO    batch     400 training time 4.90 s, testing time 0.02 s
# DEEPMD INFO    batch     500 training time 4.91 s, testing time 0.02 s
# DEEPMD INFO    batch     600 training time 4.81 s, testing time 0.02 s
# DEEPMD INFO    batch     700 training time 4.79 s, testing time 0.02 s
# DEEPMD INFO    batch     800 training time 4.80 s, testing time 0.02 s
# DEEPMD INFO    batch     900 training time 4.99 s, testing time 0.02 s
# DEEPMD INFO    batch    1000 training time 4.86 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    1100 training time 3.94 s, testing time 0.02 s
# DEEPMD INFO    batch    1200 training time 3.57 s, testing time 0.02 s
# DEEPMD INFO    batch    1300 training time 3.57 s, testing time 0.02 s
# DEEPMD INFO    batch    1400 training time 3.72 s, testing time 0.02 s
# DEEPMD INFO    batch    1500 training time 3.59 s, testing time 0.02 s
# DEEPMD INFO    batch    1600 training time 3.59 s, testing time 0.02 s
# DEEPMD INFO    batch    1700 training time 4.20 s, testing time 0.02 s
# DEEPMD INFO    batch    1800 training time 4.20 s, testing time 0.02 s
# DEEPMD INFO    batch    1900 training time 4.09 s, testing time 0.02 s
# DEEPMD INFO    batch    2000 training time 3.69 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    2100 training time 3.95 s, testing time 0.02 s
# DEEPMD INFO    batch    2200 training time 3.63 s, testing time 0.02 s
# DEEPMD INFO    batch    2300 training time 3.74 s, testing time 0.02 s
# DEEPMD INFO    batch    2400 training time 3.63 s, testing time 0.02 s
# DEEPMD INFO    batch    2500 training time 3.63 s, testing time 0.02 s
# DEEPMD INFO    batch    2600 training time 3.72 s, testing time 0.02 s
# DEEPMD INFO    batch    2700 training time 3.64 s, testing time 0.02 s
# DEEPMD INFO    batch    2800 training time 3.62 s, testing time 0.02 s
# DEEPMD INFO    batch    2900 training time 3.66 s, testing time 0.02 s
# DEEPMD INFO    batch    3000 training time 3.69 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    batch    3100 training time 4.01 s, testing time 0.02 s
# DEEPMD INFO    batch    3200 training time 3.75 s, testing time 0.02 s
# DEEPMD INFO    batch    3300 training time 3.64 s, testing time 0.02 s
# DEEPMD INFO    batch    3400 training time 3.65 s, testing time 0.02 s
# DEEPMD INFO    batch    3500 training time 3.65 s, testing time 0.02 s
# DEEPMD INFO    batch    3600 training time 3.62 s, testing time 0.02 s
# DEEPMD INFO    batch    3700 training time 3.65 s, testing time 0.02 s
# DEEPMD INFO    batch    3800 training time 3.71 s, testing time 0.02 s
# DEEPMD INFO    batch    3900 training time 3.64 s, testing time 0.02 s
# DEEPMD INFO    batch    4000 training time 3.62 s, testing time 0.02 s
# DEEPMD INFO    saved checkpoint model.ckpt
# DEEPMD INFO    finished training
# DEEPMD INFO    wall time: 166.713 s
# 2022-05-03 01:47:17.962822: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-03 01:47:17.962962: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "/home/dgg95223/venv/bin/dp", line 5, in <module>
#     from deepmd.entrypoints.main import main
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/__init__.py", line 7, in <module>
#     import deepmd.utils.network as network
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/__init__.py", line 2, in <module>
#     from .data import DeepmdData
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/utils/data.py", line 10, in <module>
#     from deepmd.env import GLOBAL_NP_FLOAT_PRECISION
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/deepmd/env.py", line 19, in <module>
#     import tensorflow.compat.v1 as tf
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/__init__.py", line 55, in <module>
#     from ._api.v2 import compat
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/__init__.py", line 39, in <module>
#     from . import v1
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/v1/__init__.py", line 34, in <module>
#     from . import compat
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py", line 39, in <module>
#     from . import v1
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/v1/compat/v1/__init__.py", line 51, in <module>
#     from tensorflow._api.v2.compat.v1 import lite
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/v1/lite/__init__.py", line 11, in <module>
#     from . import experimental
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/v1/lite/experimental/__init__.py", line 10, in <module>
#     from . import authoring
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/_api/v2/compat/v1/lite/experimental/authoring/__init__.py", line 10, in <module>
#     from tensorflow.lite.python.authoring.authoring import compatible
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/lite/python/authoring/authoring.py", line 43, in <module>
#     from tensorflow.lite.python import convert
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/lite/python/convert.py", line 33, in <module>
#     from tensorflow.lite.python import util
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/lite/python/util.py", line 34, in <module>
#     from tensorflow.lite.python import schema_py_generated as schema_fb
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/tensorflow/lite/python/schema_py_generated.py", line 7591, in <module>
#     np = import_numpy()
#   File "/home/dgg95223/venv/lib/python3.7/site-packages/flatbuffers/compat.py", line 56, in import_numpy
#     imp.find_module('numpy')
#   File "/home/dgg95223/anaconda3/lib/python3.7/imp.py", line 290, in find_module
#     if os.path.isfile(file_path):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21387/267868176.py in <module>
#      23         geo.debug = True
#      24         geo.have_init_qc_data = False
# ---> 25         geo.kernel()
#      26
#      27         Opt = optimizer.Optimizer(xyz_path="water0.xyz",
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/main.py in kernel(self)
#     115 			'''%iter)
#     116                         ML = ML_engine.MLEngine(work_path=self.work_path, ml_engine=self.ml_engine).build()
# --> 117                         ML.run()
#     118
#     119 			Opt = optimizer.Optimizer(xyz_path=self.xyz_path,
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/ML_engine.py in run(self)
#      38
#      39         self.training()
# ---> 40         self.freeze()
#      41         self.compress()
#      42         self.clear_temp()
#
# ~/backup/ML_QC_GEOM_OPT/MQGO/ML_engine.py in freeze(self)
#      25
#      26     def freeze(self):
# ---> 27         freeze = subprocess.run('dp freeze -o graph.pb', shell=True)
#      28         assert freeze.returncode == 0, 'An error occurred during freezing process.'
#      29
#
# ~/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
# --> 490             stdout, stderr = process.communicate(input, timeout=timeout)
#     491         except TimeoutExpired as exc:
#     492             process.kill()
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     954                 stderr = self.stderr.read()
#     955                 self.stderr.close()
# --> 956             self.wait()
#     957         else:
#     958             if timeout is not None:
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#    1017             endtime = _time() + timeout
#    1018         try:
# -> 1019             return self._wait(timeout=timeout)
#    1020         except KeyboardInterrupt:
#    1021             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1651                         if self.returncode is not None:
#    1652                             break  # Another thread waited.
# -> 1653                         (pid, sts) = self._try_wait(0)
#    1654                         # Check the pid and loop as waitpid has been known to
#    1655                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1609             """All callers to this function MUST hold self._waitpid_lock."""
#    1610             try:
# -> 1611                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1612             except ChildProcessError:
#    1613                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
a,b,c = data.read_xyz('water.xyz',index=1,output='regular')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16319/339447749.py in <module>
# ----> 1 a,b,c = data.read_xyz('water.xyz',index=1,output='regular')
#
# TypeError: read_xyz() got an unexpected keyword argument 'output'

# %%
mo = np.loadtxt('water.xyz',usecols=(1,2,3),skiprows=10)
# print(mo[1])
atoms =  ''
for i in range(0, len(b)):
    _mo = ''
    for j in range(0, 3):
        _mo += str(mo[i][j]) + '  '
    atoms += b[i] + '  ' + _mo + '\n'
print(atoms)

# %%
from pyscf import gto, scf, geomopt
from pyscf.data.nist import BOHR, HARTREE2EV
mol = gto.Mole(atom=atoms, basis='6-31g', spin=0).build()
mf = scf.RHF(mol)
mf.max_cycle = 500
mf.kernel()
print(mf.e_tot * HARTREE2EV)
# Out:
# converged SCF energy = -150.91286083677
# -4106.548111611891

# %%
mol_eq = mf.Gradients().optimizer(solver='berny').kernel()
# Out:
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 Internal coordinates:
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 * Number of fragments: 5
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 * Number of internal coordinates: 17
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 * Number of strong bonds: 1
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 * Number of weak bonds: 6
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 * Number of weak angles: 4
# INFO:pyscf.geomopt.berny_solver.139766248749424:0 * Number of superweak angles: 6
# Geometry optimization cycle 1
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.446142   1.122648   0.305449    0.000000  0.000000  0.000000
#    O   0.446142   1.122648  -0.305449    0.000000  0.000000  0.000000
#    H   1.120019   1.122057   1.634793    0.000000  0.000000  0.000000
#    H   0.424495  -2.593506   6.209108    0.000000  0.000000  0.000000
#    H  -0.424495  -2.593506  -6.209108    0.000000  0.000000  0.000000
#    H  -1.120019   1.122057  -1.634793    0.000000  0.000000  0.000000
# converged SCF energy = -150.912860849479
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.2725308556     0.0000039204    -0.1866346836
# 1 O    -0.2725327075     0.0000045406     0.1866358753
# 2 H     0.0013679178     0.0000026531     0.0019656291
# 3 H     0.0000603113    -0.0000074205     0.0009091055
# 4 H    -0.0000603094    -0.0000074272    -0.0009091041
# 5 H    -0.0013660678     0.0000037336    -0.0019668222
# ----------------------------------------------
# cycle 1: E = -150.912860849  dE = -150.913  norm(grad) = 0.467146
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Energy: -150.912860849
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Pseudoinverse gap of only: 1.8e+05
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Lowest eigenvalue: 7.08e-05
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * lambda: -0.513
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Quadratic step: RMS: 0.0728, max: 0.273
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Predicted energy change: -0.0682
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Total step: RMS: 0.0728, max: 0.273
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Perfect transformation to cartesians in 9 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * RMS(dcart): 2.53e-07, RMS(dq): 3.38e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Gradient RMS: 0.073 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Gradient maximum: 0.273 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:1 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 2
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.524816   1.092441   0.314712   -0.078674 -0.030208  0.009262
#    O   0.524818   1.092436  -0.314711    0.078677 -0.030212 -0.009262
#    H   1.009088   1.184344   1.681556   -0.110931  0.062287  0.046763
#    H   0.464547  -2.625579   6.197497    0.040052 -0.032073 -0.011610
#    H  -0.464549  -2.625579  -6.197501   -0.040054 -0.032073  0.011607
#    H  -1.009089   1.184337  -1.681553    0.110930  0.062280 -0.046760
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.945371540259
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0271851711    -0.0009128467     0.0162616601
# 1 O     0.0271855915    -0.0009135077    -0.0162612143
# 2 H     0.0026043494     0.0009139346     0.0043144030
# 3 H     0.0000672625    -0.0000035165     0.0009072635
# 4 H    -0.0000672622    -0.0000035173    -0.0009072635
# 5 H    -0.0026047701     0.0009194535    -0.0043148488
# ----------------------------------------------
# cycle 2: E = -150.94537154  dE = -0.0325107  norm(grad) = 0.0454176
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Energy: -150.94537154
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Change: RMS: 0.0434, max: 0.282
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Trust update: Fletcher's parameter: 0.477
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Energies: -150.94537, -150.91286
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Derivatives: -0.00813, 0.0902
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Quartic interpolation was performed: t = 0.142
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Interpolated energy: -150.94597
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Lowest eigenvalue: 7.07e-05
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * lambda: -0.0811
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Quadratic step: RMS: 0.0728, max: 0.161
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Predicted energy change: -0.0086
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Total step: RMS: 0.0722, max: 0.172
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * RMS(dcart): 1.44, RMS(dq): 0.981
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Gradient RMS: 0.0108 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Gradient maximum: 0.0276 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:2 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 3
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.534914   3.045240   0.343587   -0.010098  1.952800  0.028876
#    O   0.534973   3.045351  -0.343543    0.010154  1.952916 -0.028832
#    H   1.085955   1.829698   1.688137    0.076867  0.645354  0.006582
#    H   0.234984  -5.223685   3.425064   -0.229563 -2.598106 -2.772434
#    H  -0.235059  -5.223701  -3.425173    0.229490 -2.598121  2.772327
#    H  -1.085939   1.829494  -1.688072   -0.076850  0.645157 -0.006519
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.949321304572
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0861053085    -0.0012911932     0.0552693320
# 1 O     0.0861020750    -0.0012819666    -0.0552659348
# 2 H     0.0026259089     0.0012853084     0.0040619853
# 3 H     0.0002029408     0.0000000065     0.0029575911
# 4 H    -0.0002029408    -0.0000000065    -0.0029575910
# 5 H    -0.0026226754     0.0012878514    -0.0040653826
# ----------------------------------------------
# cycle 3: E = -150.949321305  dE = -0.00394976  norm(grad) = 0.14494
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Energy: -150.949321305
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Change: RMS: 0.0381, max: 0.417
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Trust update: Fletcher's parameter: 0.459
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Energies: -150.94932, -150.94537
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Derivatives: 0.0286, -0.0513
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * No fit succeeded, staying in new point
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Number of negative eigenvalues: 1
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Lowest eigenvalue: -0.204
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * lambda: -0.615
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Quadratic step: RMS: 0.0728, max: 0.154
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Predicted energy change: -0.0474
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Total step: RMS: 0.0728, max: 0.154
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * RMS(dcart): 0.687, RMS(dq): 0.233
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Gradient RMS: 0.0336 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Gradient maximum: 0.0985 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:3 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 4
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.576955   3.339810   0.202496   -0.042041  0.294569 -0.141091
#    O   0.577043   3.339886  -0.202455    0.042070  0.294534  0.141088
#    H   0.673804   1.973034   1.850899   -0.412152  0.143336  0.162762
#    H   0.383854  -5.661560   1.499771    0.148871 -0.437874 -1.925293
#    H  -0.383940  -5.661611  -1.499905   -0.148881 -0.437911  1.925268
#    H  -0.673806   1.972839  -1.850806    0.412133  0.143345 -0.162734
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.976289006005
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0423704642    -0.0025885898     0.0144864824
# 1 O     0.0423669326    -0.0025895068    -0.0144850580
# 2 H     0.0021853304     0.0025876126     0.0056702393
# 3 H    -0.0021148034     0.0000000725    -0.0082622955
# 4 H     0.0021148040     0.0000003626     0.0082622976
# 5 H    -0.0021817993     0.0025900490    -0.0056716657
# ----------------------------------------------
# cycle 4: E = -150.976289006  dE = -0.0269677  norm(grad) = 0.0652383
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Energy: -150.976289006
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Change: RMS: 0.0655, max: 0.298
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Trust update: Fletcher's parameter: 0.569
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Energies: -150.97629, -150.94932
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Derivatives: -0.0448, 0.0318
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Cubic interpolation was performed: t = 0.187
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Interpolated energy: -150.98025
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Lowest eigenvalue: 4.3e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * lambda: -0.2
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Quadratic step: RMS: 0.0728, max: 0.167
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Predicted energy change: -0.0226
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Total step: RMS: 0.0908, max: 0.174
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Perfect transformation to cartesians in 13 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * RMS(dcart): 2.47e-07, RMS(dq): 4.31e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Gradient RMS: 0.0406 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Gradient maximum: 0.0874 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:4 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 5
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.575369   3.289593   0.109251    0.001586 -0.050217 -0.093245
#    O   0.575543   3.289595  -0.109229   -0.001500 -0.050290  0.093226
#    H   0.386187   1.943436   1.917305   -0.287616 -0.029598  0.066405
#    H   1.075370  -5.581716   2.559132    0.691515  0.079844  1.059361
#    H  -1.075435  -5.581745  -2.559257   -0.691495  0.079866 -1.059352
#    H  -0.386296   1.943235  -1.917202    0.287510 -0.029604 -0.066395
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.967386959857
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0445587848    -0.0029213935    -0.0088456256
# 1 O    -0.0445629259    -0.0029287648     0.0088457841
# 2 H     0.0012422009     0.0029236727     0.0055797442
# 3 H     0.0016556324     0.0000000240     0.0039400008
# 4 H    -0.0016556324    -0.0000000212    -0.0039400008
# 5 H    -0.0012380598     0.0029264829    -0.0055799027
# ----------------------------------------------
# cycle 5: E = -150.96738696  dE = 0.00890205  norm(grad) = 0.0652988
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Energy: -150.96738696
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Change: RMS: 0.0446, max: 0.15
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Trust update: Fletcher's parameter: -0.393
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Energies: -150.96739, -150.97629
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Derivatives: -0.0252, 0.0395
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Quartic interpolation was performed: t = 0.728
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Interpolated energy: -150.9811
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Trust radius: 0.075
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Lowest eigenvalue: 4.69e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * lambda: -0.857
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Quadratic step: RMS: 0.0182, max: 0.0507
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Predicted energy change: -0.00599
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Total step: RMS: 0.061, max: 0.132
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Perfect transformation to cartesians in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * RMS(dcart): 9.96e-07, RMS(dq): 7.97e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Gradient RMS: 0.0277 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Gradient maximum: 0.0555 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:5 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 6
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.531537   3.314486   0.285440    0.043832  0.024893  0.176189
#    O   0.531630   3.314552  -0.285416   -0.043913  0.024957 -0.176187
#    H   0.949817   1.967818   1.732416    0.563630  0.024382 -0.184888
#    H   0.428410  -5.631005   2.189444   -0.646960 -0.049289 -0.369688
#    H  -0.428486  -5.631054  -2.189587    0.646949 -0.049309  0.369671
#    H  -0.949834   1.967601  -1.732298   -0.563538  0.024366  0.184904
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.976960246619
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0175968183    -0.0025185940     0.0091287267
# 1 O     0.0175937305    -0.0025249382    -0.0091272046
# 2 H     0.0028687315     0.0025204157     0.0050496651
# 3 H     0.0008004715     0.0000000669     0.0040906794
# 4 H    -0.0008004715    -0.0000000252    -0.0040906793
# 5 H    -0.0028656437     0.0025230748    -0.0050511872
# ----------------------------------------------
# cycle 6: E = -150.976960247  dE = -0.00957329  norm(grad) = 0.0302236
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Energy: -150.976960247
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Change: RMS: 0.0992, max: 0.586
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Trust update: Fletcher's parameter: 1.6
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Energies: -150.97696, -150.97629
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Derivatives: -0.0111, 0.0212
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Quartic interpolation was performed: t = 0.548
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Interpolated energy: -150.98057
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Trust radius: 0.15
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Lowest eigenvalue: 4.53e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * lambda: -0.233
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Quadratic step: RMS: 0.0364, max: 0.0934
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Predicted energy change: -0.00572
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Total step: RMS: 0.0316, max: 0.07
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * RMS(dcart): 0.349, RMS(dq): 0.125
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Gradient RMS: 0.0292 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Gradient maximum: 0.0656 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:6 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 7
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.613617   3.382880   0.109633   -0.082080  0.068394 -0.175808
#    O   0.613740   3.382935  -0.109600    0.082110  0.068383  0.175816
#    H   0.390580   2.001973   2.012852   -0.559236  0.034155  0.280436
#    H   0.920360  -5.733540   1.547831    0.491950 -0.102536 -0.641613
#    H  -0.920444  -5.733610  -1.547975   -0.491958 -0.102556  0.641612
#    H  -0.390619   2.001760  -2.012741    0.559215  0.034160 -0.280443
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.975665801572
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0754318687    -0.0017938871     0.0130758444
# 1 O     0.0754283725    -0.0017919368    -0.0130751951
# 2 H     0.0012761949     0.0017915747     0.0059415781
# 3 H    -0.0002975696     0.0000000819    -0.0005004311
# 4 H     0.0002975708     0.0000001104     0.0005004333
# 5 H    -0.0012726999     0.0017940569    -0.0059422296
# ----------------------------------------------
# cycle 7: E = -150.975665802  dE = 0.00129445  norm(grad) = 0.108668
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Energy: -150.975665802
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Change: RMS: 0.0928, max: 0.467
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Trust update: Fletcher's parameter: -0.226
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Energies: -150.97567, -150.97696
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Derivatives: -0.00704, 0.0103
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Quartic interpolation was performed: t = 0.649
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Interpolated energy: -150.97859
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Trust radius: 0.037
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Lowest eigenvalue: 4.49e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * lambda: -2.1
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Quadratic step: RMS: 0.0091, max: 0.0217
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Predicted energy change: -0.00315
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Total step: RMS: 0.0814, max: 0.168
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Perfect transformation to cartesians in 10 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * RMS(dcart): 5.42e-07, RMS(dq): 4.05e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Gradient RMS: 0.0187 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Gradient maximum: 0.0734 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:7 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 8
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.573932   3.359813   0.190139    0.039685 -0.023068  0.080507
#    O   0.574041   3.359873  -0.190110   -0.039699 -0.023062 -0.080510
#    H   0.648881   1.984172   1.882749    0.258301 -0.017801 -0.130104
#    H   0.623099  -5.692677   1.726383   -0.297260  0.040863  0.178552
#    H  -0.623181  -5.692741  -1.726528    0.297263  0.040869 -0.178553
#    H  -0.648909   1.983958  -1.882633   -0.258290 -0.017802  0.130108
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.980669888189
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0231805465    -0.0024479018     0.0073001098
# 1 O     0.0231772012    -0.0024532880    -0.0072992698
# 2 H     0.0020888345     0.0024491327     0.0057208997
# 3 H     0.0000346641     0.0000000919     0.0000960400
# 4 H    -0.0000346639     0.0000000897    -0.0000960396
# 5 H    -0.0020854894     0.0024518756    -0.0057217401
# ----------------------------------------------
# cycle 8: E = -150.980669888  dE = -0.00500409  norm(grad) = 0.0357675
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Energy: -150.980669888
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Change: RMS: 0.0492, max: 0.282
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Trust update: Fletcher's parameter: 1.59
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Energies: -150.98067, -150.97696
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Derivatives: -0.000111, 0.00771
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Quartic interpolation was performed: t = 0.0152
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Interpolated energy: -150.98067
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Trust radius: 0.075
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Lowest eigenvalue: 4.2e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * lambda: -0.341
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Quadratic step: RMS: 0.0182, max: 0.0483
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Predicted energy change: -0.00212
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Total step: RMS: 0.0183, max: 0.0484
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Perfect transformation to cartesians in 6 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * RMS(dcart): 6.53e-07, RMS(dq): 2.56e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Gradient RMS: 0.00792 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Gradient maximum: 0.0244 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:8 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 9
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.549488   3.385655   0.219763    0.024444  0.025842  0.029624
#    O   0.549587   3.385725  -0.219740   -0.024454  0.025852 -0.029629
#    H   0.750466   1.967627   1.812057    0.101584 -0.016545 -0.070692
#    H   0.441520  -5.701957   1.638571   -0.181579 -0.009280 -0.087813
#    H  -0.441608  -5.702045  -1.638729    0.181573 -0.009304  0.087799
#    H  -0.750477   1.967393  -1.811922   -0.101568 -0.016565  0.070711
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.981228991773
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0186200653    -0.0030158136    -0.0078323569
# 1 O    -0.0186234118    -0.0030257264     0.0078329585
# 2 H     0.0026222774     0.0030191790     0.0060443546
# 3 H    -0.0008144145     0.0000000523    -0.0030223060
# 4 H     0.0008144148     0.0000002171     0.0030223069
# 5 H    -0.0026189313     0.0030220915    -0.0060449570
# ----------------------------------------------
# cycle 9: E = -150.981228992  dE = -0.000559104  norm(grad) = 0.0309701
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Energy: -150.981228992
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Change: RMS: 0.0986, max: 0.484
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Trust update: Fletcher's parameter: 0.263
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Energies: -150.98123, -150.98067
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Derivatives: -0.00111, 0.00232
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Quartic interpolation was performed: t = 0.342
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Interpolated energy: -150.98142
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Trust radius: 0.075
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Lowest eigenvalue: 4.47e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * lambda: -0.2
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Quadratic step: RMS: 0.0182, max: 0.0326
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Predicted energy change: -0.00133
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Total step: RMS: 0.0151, max: 0.0337
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Perfect transformation to cartesians in 5 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * RMS(dcart): 8.3e-07, RMS(dq): 5.72e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Gradient RMS: 0.0146 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Gradient maximum: 0.0352 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:9 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 10
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.556813   3.397376   0.200627   -0.007325  0.011721 -0.019137
#    O   0.556922   3.397444  -0.200610    0.007335  0.011719  0.019130
#    H   0.683535   1.965304   1.825803   -0.066930 -0.002323  0.013746
#    H   0.561711  -5.711326   1.759153    0.120191 -0.009369  0.120582
#    H  -0.561802  -5.711439  -1.759324   -0.120194 -0.009394 -0.120594
#    H  -0.683553   1.965039  -1.825650    0.066924 -0.002354 -0.013728
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.982419350462
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0186029433    -0.0031909237    -0.0070851966
# 1 O    -0.0186064016    -0.0032005000     0.0070862191
# 2 H     0.0024906314     0.0031945654     0.0063350615
# 3 H     0.0000942481     0.0000000906     0.0002951539
# 4 H    -0.0000942482     0.0000000710    -0.0002951543
# 5 H    -0.0024871730     0.0031966968    -0.0063360836
# ----------------------------------------------
# cycle 10: E = -150.98241935  dE = -0.00119036  norm(grad) = 0.0304367
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Energy: -150.98241935
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Change: RMS: 0.101, max: 0.513
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Trust update: Fletcher's parameter: 0.893
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Energies: -150.98242, -150.98123
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Derivatives: 0.000294, 0.00214
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Quartic interpolation was performed: t = -0.177
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Interpolated energy: -150.98245
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Trust radius: 0.15
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Lowest eigenvalue: 4.41e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * lambda: -0.0567
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Quadratic step: RMS: 0.0364, max: 0.0621
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Predicted energy change: -0.00193
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Total step: RMS: 0.0373, max: 0.0646
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Perfect transformation to cartesians in 14 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * RMS(dcart): 6.92e-07, RMS(dq): 5.37e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Gradient RMS: 0.00798 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Gradient maximum: 0.0192 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:10 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 11
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.512373   3.430935   0.315695    0.044440  0.033560  0.115068
#    O   0.512460   3.431010  -0.315715   -0.044462  0.033566 -0.115106
#    H   1.027827   1.920081   1.616708    0.344291 -0.045223 -0.209096
#    H   0.159681  -5.699514   2.003465   -0.402030  0.011812  0.244312
#    H  -0.159795  -5.699770  -2.003717    0.402006  0.011669 -0.244393
#    H  -1.027799   1.919656  -1.616435   -0.344245 -0.045384  0.209215
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.983486784055
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0138804972    -0.0036785479     0.0081255853
# 1 O     0.0138770769    -0.0036866535    -0.0081234362
# 2 H     0.0044273735     0.0036814859     0.0067471570
# 3 H     0.0002071549     0.0000002046     0.0025983419
# 4 H    -0.0002071548    -0.0000001255    -0.0025983416
# 5 H    -0.0044239533     0.0036836363    -0.0067493064
# ----------------------------------------------
# cycle 11: E = -150.983486784  dE = -0.00106743  norm(grad) = 0.0267459
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Energy: -150.983486784
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Change: RMS: 0.107, max: 0.497
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Trust update: Fletcher's parameter: 0.552
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Energies: -150.98349, -150.98242
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Derivatives: -0.00196, 0.00261
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Quartic interpolation was performed: t = 0.236
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Interpolated energy: -150.9837
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Trust radius: 0.15
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Lowest eigenvalue: 4.55e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * lambda: -0.112
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Quadratic step: RMS: 0.0364, max: 0.078
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Predicted energy change: -0.00334
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Total step: RMS: 0.0329, max: 0.0627
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Perfect transformation to cartesians in 8 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * RMS(dcart): 7.83e-07, RMS(dq): 6.14e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Gradient RMS: 0.024 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Gradient maximum: 0.0516 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:11 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 12
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.539695   3.483830   0.256574   -0.027323  0.052894 -0.059120
#    O   0.539823   3.483891  -0.256614    0.027363  0.052881  0.059101
#    H   0.821271   1.915192   1.664610   -0.206555 -0.004889  0.047903
#    H   0.354581  -5.747495   1.806155    0.194900 -0.047981 -0.197310
#    H  -0.354695  -5.747771  -1.806424   -0.194900 -0.048002  0.197292
#    H  -0.821284   1.914752  -1.664301    0.206514 -0.004904 -0.047866
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.987475691001
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0019751419    -0.0045998542     0.0005399733
# 1 O     0.0019707205    -0.0046091870    -0.0005379158
# 2 H     0.0043102638     0.0046032782     0.0084677335
# 3 H     0.0000386893     0.0000000739     0.0001970688
# 4 H    -0.0000386891     0.0000000457    -0.0001970681
# 5 H    -0.0043058425     0.0046056434    -0.0084697916
# ----------------------------------------------
# cycle 12: E = -150.987475691  dE = -0.00398891  norm(grad) = 0.0165472
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Energy: -150.987475691
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Change: RMS: 0.0692, max: 0.25
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Trust update: Fletcher's parameter: 1.2
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Energies: -150.98748, -150.98349
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Derivatives: 0.00326, 0.00513
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * No fit succeeded, staying in new point
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Trust radius: 0.3
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Lowest eigenvalue: 4.46e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * lambda: -0.0845
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Quadratic step: RMS: 0.0728, max: 0.162
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Predicted energy change: -0.0078
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Total step: RMS: 0.0728, max: 0.162
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Perfect transformation to cartesians in 6 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * RMS(dcart): 3.09e-07, RMS(dq): 4.2e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Gradient RMS: 0.00891 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Gradient maximum: 0.0255 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:12 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 13
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.537590   3.584809   0.244033    0.002105  0.100980 -0.012541
#    O   0.537786   3.584834  -0.244151   -0.002037  0.100943  0.012463
#    H   0.730708   1.866902   1.543439   -0.090563 -0.048290 -0.121171
#    H   0.370254  -5.800093   1.724306    0.015674 -0.052597 -0.081849
#    H  -0.370371  -5.800436  -1.724636   -0.015676 -0.052665  0.081789
#    H  -0.730786   1.866381  -1.542993    0.090498 -0.048371  0.121309
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -150.997016435051
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O     0.0212198505    -0.0069236061    -0.0099989739
# 1 O    -0.0212253212    -0.0069371834     0.0100023372
# 2 H     0.0064936272     0.0069303674     0.0134365735
# 3 H    -0.0002941943    -0.0000001036    -0.0013699521
# 4 H     0.0002941943     0.0000001683     0.0013699517
# 5 H    -0.0064881565     0.0069303574    -0.0134399364
# ----------------------------------------------
# cycle 13: E = -150.997016435  dE = -0.00954074  norm(grad) = 0.0417409
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Energy: -150.997016435
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Change: RMS: 0.112, max: 0.446
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Trust update: Fletcher's parameter: 1.22
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Energies: -150.99702, -150.98748
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Derivatives: 0.0114, 0.00799
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * No fit succeeded, staying in new point
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Trust radius: 0.6
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Number of negative eigenvalues: 1
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Lowest eigenvalue: -0.0889
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * lambda: -0.143
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Quadratic step: RMS: 0.146, max: 0.264
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Predicted energy change: -0.0376
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Total step: RMS: 0.146, max: 0.264
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Perfect transformation to cartesians in 14 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * RMS(dcart): 6.6e-07, RMS(dq): 9.57e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Gradient RMS: 0.012 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Gradient maximum: 0.0246 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:13 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 14
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.610571   3.696275   0.127625   -0.072981  0.111466 -0.116408
#    O   0.611036   3.696184  -0.127817    0.073250  0.111350  0.116334
#    H   0.326167   1.782777   1.424775   -0.404540 -0.084125 -0.118664
#    H   0.848266  -5.827477   2.282050    0.478012 -0.027384  0.557743
#    H  -0.848311  -5.827699  -2.282333   -0.477940 -0.027263 -0.557697
#    H  -0.326587   1.782338  -1.424301    0.404199 -0.084044  0.118692
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -151.011789737317
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0790657254    -0.0102175702     0.0162540541
# 1 O     0.0790548432    -0.0102470894    -0.0162493719
# 2 H     0.0065107093     0.0102338326     0.0278672126
# 3 H     0.0016050899     0.0000002059     0.0043182478
# 4 H    -0.0016050899    -0.0000002149    -0.0043182478
# 5 H    -0.0064998271     0.0102308360    -0.0278718948
# ----------------------------------------------
# cycle 14: E = -151.011789737  dE = -0.0147733  norm(grad) = 0.122998
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Energy: -151.011789737
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Change: RMS: 0.158, max: 0.88
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Trust update: Fletcher's parameter: 0.393
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Energies: -151.01179, -150.99702
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Derivatives: 0.00982, 0.0237
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * No fit succeeded, staying in new point
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Trust radius: 0.6
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Lowest eigenvalue: 3.74e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * lambda: -0.0696
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Quadratic step: RMS: 0.146, max: 0.331
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Predicted energy change: -0.0328
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Total step: RMS: 0.146, max: 0.331
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * RMS(dcart): 0.146, RMS(dq): 0.141
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Gradient RMS: 0.0483 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Gradient maximum: 0.112 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:14 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 15
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.625279   3.843891   0.182412   -0.014707  0.147615  0.054787
#    O   0.625823   3.843808  -0.182745    0.014788  0.147625 -0.054929
#    H   0.359511   1.700224   1.064958    0.033343 -0.082554 -0.359818
#    H   0.725605  -5.892512   2.183834   -0.122661 -0.065035 -0.098216
#    H  -0.725649  -5.892736  -2.184182    0.122662 -0.065037  0.098152
#    H  -0.360011   1.699723  -1.064278   -0.033424 -0.082614  0.360023
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -151.066495204418
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.1297144801    -0.0121415759     0.0375607230
# 1 O     0.1297033201    -0.0121776819    -0.0375523987
# 2 H     0.0186353664     0.0121703048     0.0546016415
# 3 H     0.0013886085     0.0000001907     0.0041794655
# 4 H    -0.0013886085    -0.0000002392    -0.0041794656
# 5 H    -0.0186242064     0.0121490014    -0.0546099658
# ----------------------------------------------
# cycle 15: E = -151.066495204  dE = -0.0547055  norm(grad) = 0.209183
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Energy: -151.066495204
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Change: RMS: 0.125, max: 0.547
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Trust update: Fletcher's parameter: 1.67
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Energies: -151.0665, -151.01179
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Derivatives: 0.0725, 0.0402
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * No fit succeeded, staying in new point
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Trust radius: 1.2
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Number of negative eigenvalues: 1
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Lowest eigenvalue: -0.135
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * lambda: -0.306
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Quadratic step: RMS: 0.291, max: 0.773
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Predicted energy change: -0.361
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Total step: RMS: 0.291, max: 0.773
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * RMS(dcart): 1.33, RMS(dq): 0.627
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Gradient RMS: 0.0737 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Gradient maximum: 0.178 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:15 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 16
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
# ...
# 3 H     0.0454205535    -0.0005762800    -0.0163547690
# 4 H    -0.0454206426     0.0005763104     0.0163547984
# 5 H     0.0022608956     0.0008646041    -0.0007478330
# ----------------------------------------------
# cycle 59: E = -151.433807462  dE = -3.68823e-07  norm(grad) = 0.0687375
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Energy: -151.433807462
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Change: RMS: 9.9e+06, max: 4.23e+07
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Trust update: Fletcher's parameter: 0.0222
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Energies: -151.43381, -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Derivatives: 1.66e-05, 1.66e-05
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Cubic interpolation was performed: t = 1.0
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Interpolated energy: -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Trust radius: 9.3e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Lowest eigenvalue: 2.13e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * lambda: 3.24
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Quadratic step: RMS: 0.0453, max: 0.106
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Predicted energy change: 0.0968
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Total step: RMS: 0.0453, max: 0.106
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * RMS(dcart): 0.22, RMS(dq): 0.111
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Gradient RMS: 0.334 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Gradient maximum: 0.713 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:59 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 60
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O  -0.162787   4.431368   0.706069   -0.352798 -0.025610  0.130196
#    O   0.468580   4.440786  -0.532124    0.344078 -0.006893  0.086122
#    H   0.241479   1.531537  -0.132449    0.104669 -0.012879 -0.033077
#    H   1.609612  -6.372718  -0.775551    0.335250  0.032629 -0.332842
#    H  -1.525679  -6.345020   0.854616   -0.342248  0.029136  0.412337
#    H  -0.631205   1.616446  -0.120561   -0.088949 -0.016382 -0.262737
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -151.319946636363
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0834234636    -0.0026729401     0.1630316849
# 1 O     0.0830686234    -0.0002478323    -0.1632438620
# 2 H     0.0739045458    -0.0056673697    -0.0009862253
# 3 H     0.0201201530    -0.0001776908    -0.0104612741
# 4 H    -0.0201201865     0.0001777410     0.0104612801
# 5 H    -0.0735496721     0.0085880919     0.0011983965
# ----------------------------------------------
# cycle 60: E = -151.319946636  dE = 0.113861  norm(grad) = 0.281253
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Energy: -151.319946636
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Change: RMS: 1.09e+07, max: 4.66e+07
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Trust update: Fletcher's parameter: 1.18
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Energies: -151.31995, -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Derivatives: -0.152, -0.0782
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * No fit succeeded, returning to best point
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Trust radius: 9.3e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Number of negative eigenvalues: 0
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Lowest eigenvalue: 1.12e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * lambda: -4.83e+04
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Quadratic step: RMS: 2.26e-06, max: 4.65e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Predicted energy change: -4.18e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Total step: RMS: 0.111, max: 0.367
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Transformation did not converge in 20 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * RMS(dcart): 0.276, RMS(dq): 0.0652
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Gradient RMS: 0.185 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Gradient maximum: 0.379 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:60 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 61
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   0.137024   4.484240   0.648516    0.299811  0.052872 -0.057553
#    O   0.242751   4.463094  -0.640330   -0.225830  0.022308 -0.108205
#    H   0.109420   1.559569  -0.106541   -0.132059  0.028033  0.025908
#    H   1.035586  -6.445206  -0.336179   -0.574026 -0.072488  0.439372
#    H  -0.919593  -6.419539   0.353574    0.606086 -0.074519 -0.501042
#    H  -0.605187   1.660240   0.080960    0.026017  0.043794  0.201521
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -151.480361358375
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0104668823     0.0008894901     0.1251281655
# 1 O     0.0101029115    -0.0032725402    -0.1251338811
# 2 H     0.0120296673    -0.0004431966    -0.0031476873
# 3 H     0.0665449699    -0.0008733306    -0.0234758971
# 4 H    -0.0665451000     0.0008733946     0.0234759313
# 5 H    -0.0116655664     0.0028261828     0.0031533687
# ----------------------------------------------
# cycle 61: E = -151.480361358  dE = -0.160415  norm(grad) = 0.204469
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Energy: -151.480361358
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Change: RMS: 10.4, max: 33.9
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Trust update: Fletcher's parameter: 3.84e+04
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Energies: -151.48036, -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Derivatives: 0.0433, -0.00164
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * No fit succeeded, returning to best point
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Trust radius: 1.9e-05
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Number of negative eigenvalues: 1
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Lowest eigenvalue: -40.5
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * lambda: -2.42e+04
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Quadratic step: RMS: 4.51e-06, max: 9.29e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Predicted energy change: -8.37e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Total step: RMS: 0.0605, max: 0.184
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Perfect transformation to cartesians in 10 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * RMS(dcart): 4.2e-07, RMS(dq): 2.51e-07
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Gradient RMS: 0.487 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Gradient maximum: 1.16 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:61 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 62
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   0.164232   4.457047   0.583190    0.027209 -0.027193 -0.065325
#    O   0.151245   4.447623  -0.612653   -0.091506 -0.015470  0.027677
#    H   0.140940   1.544413  -0.093449    0.031521 -0.015156  0.013092
#    H   1.293018  -6.405298  -0.385759    0.257432  0.039908 -0.049580
#    H  -1.201346  -6.374190   0.390625   -0.281753  0.045349  0.037051
#    H  -0.548090   1.632803   0.118045    0.057098 -0.027437  0.037085
#
# WARN: Large deviations found between the input molecule and the molecule from chkfile
# Initial guess density matrix may have large error.
#
# converged SCF energy = -151.43379615614
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0001055252    -0.0011163238     0.0048820027
# 1 O    -0.0001875197    -0.0012152624    -0.0048580714
# 2 H    -0.0019915948     0.0014696139     0.0006223835
# 3 H     0.0460897644    -0.0005746627    -0.0143456863
# 4 H    -0.0460898567     0.0005746932     0.0143457120
# 5 H     0.0022847319     0.0008619419    -0.0006463405
# ----------------------------------------------
# cycle 62: E = -151.433796156  dE = 0.0465652  norm(grad) = 0.0687306
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Energy: -151.433796156
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Change: RMS: 3.27e+04, max: 1.4e+05
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Trust update: Fletcher's parameter: -5.56e+03
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Energies: -151.4338, -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Derivatives: 5e-06, 8.34e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Cubic interpolation was performed: t = 1.0
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Interpolated energy: -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Minimization on sphere was performed:
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Trust radius: 4.7e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Number of negative eigenvalues: 1
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Lowest eigenvalue: -4.96
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * lambda: -9.59e+04
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Quadratic step: RMS: 1.13e-06, max: 2.52e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Predicted energy change: -2.08e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Total step: RMS: 3.38e-06, max: 6.77e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Perfect transformation to cartesians in 2 iterations
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * RMS(dcart): 8.03e-10, RMS(dq): 7.48e-10
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 Convergence criteria:
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Gradient RMS: 0.334 > 0.00015 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Gradient maximum: 0.713 > 0.00045 => no
# INFO:pyscf.geomopt.berny_solver.139766248749424:62 * Minimization on sphere: Minimization on sphere => no
# Geometry optimization cycle 63
# Cartesian coordinates (Angstrom)
#  Atom        New coordinates             dX        dY        dZ
#    O   0.164202   4.457046   0.583199   -0.000031 -0.000000  0.000008
#    O   0.151273   4.447623  -0.612645    0.000029 -0.000000  0.000007
#    H   0.140946   1.544413  -0.093450    0.000006 -0.000000 -0.000001
#    H   1.293028  -6.405297  -0.385780    0.000010  0.000001 -0.000020
#    H  -1.201357  -6.374189   0.390651   -0.000011  0.000001  0.000026
#    H  -0.548092   1.632801   0.118026   -0.000002 -0.000001 -0.000020
# converged SCF energy = -151.433793116824
# --------------- SCF_Scanner gradients ---------------
#          x                y                z
# 0 O    -0.0001079835    -0.0011162774     0.0048824408
# 1 O    -0.0001850590    -0.0012153107    -0.0048585231
# 2 H    -0.0019902156     0.0014694454     0.0006219012
# 3 H     0.0460884107    -0.0005746361    -0.0143460005
# 4 H    -0.0460885031     0.0005746666     0.0143460262
# 5 H     0.0022833504     0.0008621122    -0.0006458446
# ----------------------------------------------
# cycle 63: E = -151.433793117  dE = 3.03932e-06  norm(grad) = 0.0687289
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 Energy: -151.433793117
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 Hessian update information:
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 * Change: RMS: 8.49e+05, max: 3.63e+06
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 Trust update: Fletcher's parameter: -1.46
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 Linear interpolation:
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 * Energies: -151.43379, -151.71392
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 * Derivatives: 1.96e-06, 2.08e-06
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 * Cubic interpolation was performed: t = 1.0
# INFO:pyscf.geomopt.berny_solver.139766248749424:63 * Interpolated energy: -151.71392
# /home/jingheng/anaconda3/lib/python3.9/site-packages/berny/Math.py:135: RuntimeWarning: divide by zero encountered in double_scalars
#   x = x - fx / dxf
# /home/jingheng/anaconda3/lib/python3.9/site-packages/berny/berny.py:243: RuntimeWarning: invalid value encountered in multiply
#   return norm(np.linalg.solve(l * eye(H.shape[0]) - H, g)) - trust
# ---------------------------------------------------------------------------
# FindrootException                         Traceback (most recent call last)
# /tmp/ipykernel_20326/1575364510.py in <module>
# ----> 1 mol_eq = mf.Gradients().optimizer(solver='berny').kernel()
#
# ~/pyscf/pyscf/geomopt/berny_solver.py in kernel(self, params)
#     213         params['maxsteps'] = self.max_cycle
#     214         self.converged, self.mol = \
# --> 215                 kernel(self.method, callback=self.callback, **params)
#     216         return self.mol
#     217     optimize = kernel
#
# ~/pyscf/pyscf/geomopt/berny_solver.py in kernel(method, assert_convergence, include_ghost, callback, **kwargs)
#     162         if assert_convergence and not g_scanner.converged:
#     163             raise RuntimeError('Nuclear gradients of %s not converged' % method)
# --> 164         optimizer.send((energy, gradients))
#     165         t1 = log.timer('geomoetry optimization cycle %d'%cycle, *t1)
#     166
#
# ~/anaconda3/lib/python3.9/site-packages/berny/berny.py in send(self, energy_and_gradients)
#     152         proj = dot(B, B_inv)
#     153         H_proj = proj.dot(s.H).dot(proj) + 1000 * (eye(len(s.coords)) - proj)
# --> 154         dq, dE, on_sphere = quadratic_step(
#     155             dot(proj, s.interpolated.g), H_proj, s.weights, s.trust, log=log
#     156         )
#
# ~/anaconda3/lib/python3.9/site-packages/berny/berny.py in quadratic_step(g, H, w, trust, log)
#     243             return norm(np.linalg.solve(l * eye(H.shape[0]) - H, g)) - trust
#     244
# --> 245         l = Math.findroot(steplength, ev[0])  # minimization on sphere
#     246         dq = np.linalg.solve(l * eye(H.shape[0]) - H, g)
#     247         on_sphere = True
#
# ~/anaconda3/lib/python3.9/site-packages/berny/Math.py in findroot(f, lim)
#     140         err = err_new
#     141     else:
# --> 142         raise FindrootException()
#
# FindrootException:

# %%
print(-151.433793117*HARTREE2EV)
# Out:
# -4120.723400979506
